# %%
# !wget http://www.phontron.com/download/conala-corpus-v1.1.zip -O conala-corpus-v1.1.zip
# !unzip conala-corpus-v1.1.zip -d conala_dataset
# Out:
# --2024-12-06 03:25:10--  http://www.phontron.com/download/conala-corpus-v1.1.zip
# Resolving www.phontron.com (www.phontron.com)... 173.236.247.185
# Connecting to www.phontron.com (www.phontron.com)|173.236.247.185|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 52105440 (50M) [application/zip]
# Saving to: ‘conala-corpus-v1.1.zip’
#
# conala-corpus-v1.1. 100%[===================>]  49.69M  39.2MB/s    in 1.3s
#
# 2024-12-06 03:25:11 (39.2 MB/s) - ‘conala-corpus-v1.1.zip’ saved [52105440/52105440]
#
# Archive:  conala-corpus-v1.1.zip
#    creating: conala_dataset/conala-corpus/
#   inflating: conala_dataset/conala-corpus/conala-mined.jsonl
#   inflating: conala_dataset/conala-corpus/conala-train.json
#   inflating: conala_dataset/conala-corpus/conala-test.json

# %%
import json
import os
# Define the path to the JSON file
json_path = '/content/conala_dataset/conala-corpus/conala-test.json'

# Open and load the JSON file
with open(json_path, 'r', encoding='utf-8') as f:
    data = json.load(f)

# %%
# comment
print(data[0]['rewritten_intent'])
# code
print(data[0]['snippet'])
# Out:
# send a signal `signal.SIGUSR1` to the current process
# os.kill(os.getpid(), signal.SIGUSR1)

# %%
import pandas as pd

df = pd.DataFrame(data)

# %%
df
# Out:
#                                                 intent  \
# 0       How can I send a signal from a python program?
# 1                        Decode Hex String in Python 3
# 2        check if all elements in a list are identical
# 3                            Format string dynamically
# 4       How to convert a string from CP-1251 to UTF-8?
# ..                                                 ...
# 495  Using Regular Expressions to extract specific ...
# 496  Is there a function in Python to split a strin...
# 497                                Open file in Python
# 498           Sum of multiple list of lists index wise
# 499  numpy: syntax/idiom to cast (n,) array to a (n...
#
#                                       rewritten_intent  \
# 0    send a signal `signal.SIGUSR1` to the current ...
# 1               decode a hex string '4a4b4c' to UTF-8.
# 2    check if all elements in list `myList` are ide...
# 3    format number of spaces between strings `Pytho...
# 4                                                 None
# ..                                                 ...
# 495  match urls whose domain doesn't start with `t`...
# 496  split a string `mystring` considering the spac...
# 497                     open file `path` with mode 'r'
# 498      sum elements at the same index in list `data`
# 499                        add a new axis to array `a`
#
#                                                snippet  question_id
# 0                 os.kill(os.getpid(), signal.SIGUSR1)     15080500
# 1              bytes.fromhex('4a4b4c').decode('utf-8')      3283984
# 2                  all(x == myList[0] for x in myList)      3844801
# 3    print('%*s : %*s' % (20, 'Python', 20, 'Very G...      4302166
# 4                    d.decode('cp1251').encode('utf8')      7555335
# ..                                                 ...          ...
# 495   re.findall('http://[^t][^s"]+\\.html', document)     30551576
# 496            mystring.replace(' ', '! !').split('!')       113534
# 497                                    open(path, 'r')      5838735
# 498  [[sum(item) for item in zip(*items)] for items...     36003967
# 499                                 a[:, (np.newaxis)]      7635237
#
# [500 rows x 4 columns]

# %%
df = df[['snippet','rewritten_intent']]

# %%
df = df.dropna()

# %%
# Access the first example
first_example = df.iloc[0]
print("Docstring:\n", first_example['rewritten_intent'])
print()
print("Code:\n", first_example['snippet'])
# Out:
# Docstring:
#  send a signal `signal.SIGUSR1` to the current process
#
# Code:
#  os.kill(os.getpid(), signal.SIGUSR1)

# %%
#remove any non-english comments.
# From https://stackoverflow.com/a/27084708/5768407


def isASCII(s):
    try:
        s.encode(encoding='utf-8').decode('ascii')
    except UnicodeDecodeError:
        return False
    else:
        return True

df = df[df['rewritten_intent'].apply(lambda x: isASCII(x))]

# %%
df = df[~(df['rewritten_intent'] == '')]

# %%
df = df[~df['rewritten_intent'].duplicated()]

# %%
len(df)
# Out:
# 450

# %%
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity
import numpy as np

# %%
from transformers import AutoTokenizer, AutoModelWithLMHead, SummarizationPipeline


# source: https://huggingface.co/SEBIS/code_trans_t5_base_code_documentation_generation_python
pipeline = SummarizationPipeline(
    model=AutoModelWithLMHead.from_pretrained("SEBIS/code_trans_t5_base_code_documentation_generation_python"),
    tokenizer=AutoTokenizer.from_pretrained("SEBIS/code_trans_t5_base_code_documentation_generation_python", skip_special_tokens=True),
    device=0
)

tokenized_code = df.iloc[0]['rewritten_intent']
pipeline([tokenized_code])[0]['summary_text']
# Out:
# Your max_length is set to 20, but your input_length is only 16. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=8)
# /usr/local/lib/python3.10/dist-packages/transformers/generation/utils.py:1375: UserWarning: Using the model-agnostic default `max_length` (=20) to control the generation length. We recommend setting `max_new_tokens` to control the maximum length of the generation.
#   warnings.warn(
# 'Process the current signal .'

# %%
import re
from tqdm import tqdm
import pandas as pd

# %%
generated_comments = []
reference_comments = []

# Iterate over the test set
for _, row in tqdm(df.iterrows(), total=df.shape[0]):
    code = row['snippet']
    reference = row['rewritten_intent']



    # Generate the comment
    generated_comment = pipeline([code])[0]['summary_text'].strip()

    generated_comments.append(generated_comment)
    reference_comments.append(reference)
# Out:
#   0%|          | 0/450 [00:00<?, ?it/s]Your max_length is set to 20, but your input_length is only 17. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=8)
# /usr/local/lib/python3.10/dist-packages/transformers/generation/utils.py:1375: UserWarning: Using the model-agnostic default `max_length` (=20) to control the generation length. We recommend setting `max_new_tokens` to control the maximum length of the generation.
#   warnings.warn(
#   0%|          | 1/450 [00:00<03:20,  2.24it/s]Your max_length is set to 20, but your input_length is only 19. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=9)
#   0%|          | 2/450 [00:01<04:40,  1.60it/s]Your max_length is set to 20, but your input_length is only 14. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=7)
#   1%|▏         | 6/450 [00:05<07:55,  1.07s/it]Your max_length is set to 20, but your input_length is only 15. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=7)
#   2%|▏         | 8/450 [00:05<04:43,  1.56it/s]Your max_length is set to 20, but your input_length is only 15. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=7)
#   2%|▏         | 9/450 [00:06<03:49,  1.92it/s]You seem to be using the pipelines sequentially on GPU. In order to maximize efficiency please use a dataset
#   2%|▏         | 10/450 [00:06<03:26,  2.13it/s]Your max_length is set to 20, but your input_length is only 9. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=4)
#   2%|▏         | 11/450 [00:07<03:36,  2.03it/s]Your max_length is set to 20, but your input_length is only 18. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=9)
#   3%|▎         | 12/450 [00:07<02:44,  2.67it/s]Your max_length is set to 20, but your input_length is only 16. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=8)
#   3%|▎         | 13/450 [00:07<02:31,  2.88it/s]Your max_length is set to 20, but your input_length is only 12. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=6)
#   3%|▎         | 14/450 [00:07<02:24,  3.01it/s]Your max_length is set to 20, but your input_length is only 8. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=4)
#   3%|▎         | 15/450 [00:08<02:34,  2.82it/s]Your max_length is set to 20, but your input_length is only 8. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=4)
#   4%|▎         | 16/450 [00:08<02:26,  2.97it/s]Your max_length is set to 20, but your input_length is only 14. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=7)
#   4%|▍         | 18/450 [00:09<02:48,  2.57it/s]Your max_length is set to 20, but your input_length is only 17. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=8)
#   4%|▍         | 19/450 [00:09<02:33,  2.80it/s]Your max_length is set to 20, but your input_length is only 16. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=8)
#   4%|▍         | 20/450 [00:09<02:44,  2.62it/s]Your max_length is set to 20, but your input_length is only 15. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=7)
#   5%|▍         | 21/450 [00:10<02:59,  2.39it/s]Your max_length is set to 20, but your input_length is only 17. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=8)
#   5%|▍         | 22/450 [00:10<02:37,  2.72it/s]Your max_length is set to 20, but your input_length is only 12. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=6)
#   6%|▌         | 26/450 [00:12<02:22,  2.98it/s]Your max_length is set to 20, but your input_length is only 9. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=4)
#   6%|▋         | 29/450 [00:13<02:15,  3.10it/s]Your max_length is set to 20, but your input_length is only 19. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=9)
#   7%|▋         | 31/450 [00:13<02:16,  3.07it/s]Your max_length is set to 20, but your input_length is only 8. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=4)
#   7%|▋         | 32/450 [00:14<02:38,  2.64it/s]Your max_length is set to 20, but your input_length is only 8. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=4)
#   7%|▋         | 33/450 [00:14<02:52,  2.42it/s]Your max_length is set to 20, but your input_length is only 9. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=4)
#   8%|▊         | 34/450 [00:15<02:36,  2.65it/s]Your max_length is set to 20, but your input_length is only 18. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=9)
#   8%|▊         | 36/450 [00:16<03:12,  2.15it/s]Your max_length is set to 20, but your input_length is only 12. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=6)
#   8%|▊         | 37/450 [00:16<03:08,  2.19it/s]Your max_length is set to 20, but your input_length is only 15. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=7)
#   9%|▉         | 42/450 [00:18<02:45,  2.47it/s]Your max_length is set to 20, but your input_length is only 13. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=6)
#  10%|▉         | 43/450 [00:18<02:47,  2.42it/s]Your max_length is set to 20, but your input_length is only 9. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=4)
#  10%|▉         | 44/450 [00:19<02:26,  2.77it/s]Your max_length is set to 20, but your input_length is only 15. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=7)
#  10%|█         | 45/450 [00:19<02:44,  2.46it/s]Your max_length is set to 20, but your input_length is only 13. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=6)
#  10%|█         | 46/450 [00:20<02:39,  2.53it/s]Your max_length is set to 20, but your input_length is only 18. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=9)
#  10%|█         | 47/450 [00:20<02:43,  2.46it/s]Your max_length is set to 20, but your input_length is only 17. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=8)
#  11%|█▏        | 51/450 [00:21<01:55,  3.45it/s]Your max_length is set to 20, but your input_length is only 14. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=7)
#  12%|█▏        | 53/450 [00:22<02:16,  2.90it/s]Your max_length is set to 20, but your input_length is only 17. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=8)
#  13%|█▎        | 60/450 [00:24<02:18,  2.82it/s]Your max_length is set to 20, but your input_length is only 19. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=9)
#  14%|█▎        | 61/450 [00:25<02:06,  3.08it/s]Your max_length is set to 20, but your input_length is only 7. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=3)
#  14%|█▍        | 64/450 [00:26<02:27,  2.62it/s]Your max_length is set to 20, but your input_length is only 12. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=6)
#  14%|█▍        | 65/450 [00:26<02:06,  3.04it/s]Your max_length is set to 20, but your input_length is only 14. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=7)
#  15%|█▌        | 68/450 [00:27<02:33,  2.48it/s]Your max_length is set to 20, but your input_length is only 14. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=7)
#
/s]Your max_length is set to 20, but your input_length is only 15. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=7)
#  95%|█████████▍| 426/450 [02:14<00:04,  5.25it/s]Your max_length is set to 20, but your input_length is only 18. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=9)
#  95%|█████████▌| 428/450 [02:15<00:05,  3.90it/s]Your max_length is set to 20, but your input_length is only 10. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=5)
#  95%|█████████▌| 429/450 [02:15<00:05,  4.13it/s]Your max_length is set to 20, but your input_length is only 10. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=5)
#  96%|█████████▌| 432/450 [02:16<00:05,  3.23it/s]Your max_length is set to 20, but your input_length is only 10. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=5)
#  96%|█████████▋| 434/450 [02:17<00:05,  2.95it/s]Your max_length is set to 20, but your input_length is only 16. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=8)
#  97%|█████████▋| 435/450 [02:17<00:05,  2.84it/s]Your max_length is set to 20, but your input_length is only 18. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=9)
#  97%|█████████▋| 436/450 [02:18<00:05,  2.51it/s]Your max_length is set to 20, but your input_length is only 16. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=8)
#  97%|█████████▋| 437/450 [02:18<00:04,  3.00it/s]Your max_length is set to 20, but your input_length is only 14. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=7)
#  97%|█████████▋| 438/450 [02:18<00:04,  2.98it/s]Your max_length is set to 20, but your input_length is only 13. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=6)
#  98%|█████████▊| 439/450 [02:18<00:03,  3.14it/s]Your max_length is set to 20, but your input_length is only 7. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=3)
#  98%|█████████▊| 441/450 [02:19<00:02,  3.20it/s]Your max_length is set to 20, but your input_length is only 16. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=8)
#  98%|█████████▊| 442/450 [02:19<00:02,  3.37it/s]Your max_length is set to 20, but your input_length is only 14. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=7)
#  98%|█████████▊| 443/450 [02:20<00:02,  3.42it/s]Your max_length is set to 20, but your input_length is only 15. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=7)
#  99%|█████████▉| 446/450 [02:20<00:01,  3.82it/s]Your max_length is set to 20, but your input_length is only 16. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=8)
#  99%|█████████▉| 447/450 [02:20<00:00,  3.99it/s]Your max_length is set to 20, but your input_length is only 8. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=4)
# 100%|█████████▉| 449/450 [02:21<00:00,  4.50it/s]Your max_length is set to 20, but your input_length is only 10. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=5)
# 100%|██████████| 450/450 [02:21<00:00,  3.18it/s]

# %%
# !pip install rouge-score
# Out:
# Collecting rouge-score
#   Downloading rouge_score-0.1.2.tar.gz (17 kB)
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: absl-py in /usr/local/lib/python3.10/dist-packages (from rouge-score) (1.4.0)
# Requirement already satisfied: nltk in /usr/local/lib/python3.10/dist-packages (from rouge-score) (3.9.1)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from rouge-score) (1.26.4)
# Requirement already satisfied: six>=1.14.0 in /usr/local/lib/python3.10/dist-packages (from rouge-score) (1.16.0)
# Requirement already satisfied: click in /usr/local/lib/python3.10/dist-packages (from nltk->rouge-score) (8.1.7)
# Requirement already satisfied: joblib in /usr/local/lib/python3.10/dist-packages (from nltk->rouge-score) (1.4.2)
# Requirement already satisfied: regex>=2021.8.3 in /usr/local/lib/python3.10/dist-packages (from nltk->rouge-score) (2024.9.11)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from nltk->rouge-score) (4.66.6)
# Building wheels for collected packages: rouge-score
#   Building wheel for rouge-score (setup.py) ... done
#   Created wheel for rouge-score: filename=rouge_score-0.1.2-py3-none-any.whl size=24935 sha256=0d5c91f6248f346b938c0c74b95132aef7c74bbf2a37fc248b7d1fdfb073bb00
#   Stored in directory: /root/.cache/pip/wheels/5f/dd/89/461065a73be61a532ff8599a28e9beef17985c9e9c31e541b4
# Successfully built rouge-score
# Installing collected packages: rouge-score
# Successfully installed rouge-score-0.1.2

# %%
from nltk.translate.bleu_score import corpus_bleu
from rouge_score import rouge_scorer
from nltk.translate.meteor_score import meteor_score
import nltk
nltk.download('punkt')
nltk.download('punkt_tab')
nltk.download('wordnet')
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# [nltk_data] Downloading package punkt_tab to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt_tab.zip.
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# True

# %%
def evaluate_generated_comments(reference_comments, generated_comments):

    # Tokenize for BLEU
    tokenized_generated = [nltk.word_tokenize(comment.lower()) for comment in generated_comments]
    tokenized_reference = [[nltk.word_tokenize(ref.lower())] for ref in reference_comments]

    # BLEU-2
    bleu_score = corpus_bleu(tokenized_reference, tokenized_generated, weights=(0.5, 0.5))  # BLEU-2

    # ROUGE
    scorer = rouge_scorer.RougeScorer(['rouge1', 'rouge2', 'rougeL'], use_stemmer=True)
    rouge1, rouge2, rougeL = 0, 0, 0
    for ref, gen in zip(reference_comments, generated_comments):
        scores = scorer.score(ref, gen)
        rouge1 += scores['rouge1'].fmeasure
        rouge2 += scores['rouge2'].fmeasure
        rougeL += scores['rougeL'].fmeasure
    rouge1 /= len(reference_comments)
    rouge2 /= len(reference_comments)
    rougeL /= len(reference_comments)

    # METEOR
    meteor = 0
    for ref, gen in zip(reference_comments, generated_comments):
        # Tokenize the hypothesis and references
        ref_tokens = nltk.word_tokenize(ref.lower())
        gen_tokens = nltk.word_tokenize(gen.lower())

        # Compute METEOR for each pair
        meteor += meteor_score([ref_tokens], gen_tokens)
    meteor /= len(reference_comments)

    return {
        'BLEU-2': bleu_score,
        'ROUGE-1': rouge1,
        'ROUGE-2': rouge2,
        'ROUGE-L': rougeL,
        'METEOR': meteor
    }

# %%
metrics = evaluate_generated_comments(reference_comments, generated_comments)
for metric, score in metrics.items():
    print(f"{metric}: {score:.4f}")
# Out:
# BLEU-2: 0.0395
# ROUGE-1: 0.1902
# ROUGE-2: 0.0253
# ROUGE-L: 0.1617
# METEOR: 0.0830

# %%
from sentence_transformers import SentenceTransformer
from sklearn.metrics.pairwise import cosine_similarity

# %%
# Load a pre-trained Sentence-BERT model
model = SentenceTransformer('all-MiniLM-L6-v2')
# Out:
# modules.json:   0%|          | 0.00/349 [00:00<?, ?B/s]
# config_sentence_transformers.json:   0%|          | 0.00/116 [00:00<?, ?B/s]
# README.md:   0%|          | 0.00/10.7k [00:00<?, ?B/s]
# sentence_bert_config.json:   0%|          | 0.00/53.0 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/612 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/90.9M [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/350 [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/232k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/466k [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/112 [00:00<?, ?B/s]
# 1_Pooling/config.json:   0%|          | 0.00/190 [00:00<?, ?B/s]

# %%
# Encode the comments to get their embeddings
embeddings_ref = model.encode(reference_comments)
embeddings_gen = model.encode(generated_comments)

# %%
# Compute cosine similarity for each pair
similarity_scores = cosine_similarity(embeddings_ref, embeddings_gen).diagonal()

# Calculate average similarity
average_similarity = similarity_scores.mean()



print(f"\nAverage Cosine Similarity: {average_similarity:.4f}")
# Out:
# Average Cosine Similarity: 0.3252

# %%
reference_comments[0], generated_comments[0]
# Out:
# ('send a signal `signal.SIGUSR1` to the current process',
#  'This signals module in which PID is properly called')
