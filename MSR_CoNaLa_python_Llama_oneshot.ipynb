# %%
#python

# %%
# !pip install datasets pandas scikit-learn matplotlib torch
# !pip install -U bitsandbytes
# Out:
# Collecting datasets
#   Downloading datasets-3.2.0-py3-none-any.whl.metadata (20 kB)
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (2.2.2)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.10/dist-packages (1.5.2)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.10/dist-packages (3.8.0)
# Requirement already satisfied: torch in /usr/local/lib/python3.10/dist-packages (2.5.1+cu121)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from datasets) (3.16.1)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.10/dist-packages (from datasets) (1.26.4)
# Requirement already satisfied: pyarrow>=15.0.0 in /usr/local/lib/python3.10/dist-packages (from datasets) (17.0.0)
# Collecting dill<0.3.9,>=0.3.0 (from datasets)
#   Downloading dill-0.3.8-py3-none-any.whl.metadata (10 kB)
# Requirement already satisfied: requests>=2.32.2 in /usr/local/lib/python3.10/dist-packages (from datasets) (2.32.3)
# Requirement already satisfied: tqdm>=4.66.3 in /usr/local/lib/python3.10/dist-packages (from datasets) (4.66.6)
# Collecting xxhash (from datasets)
#   Downloading xxhash-3.5.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (12 kB)
# Collecting multiprocess<0.70.17 (from datasets)
#   Downloading multiprocess-0.70.16-py310-none-any.whl.metadata (7.2 kB)
# Collecting fsspec<=2024.9.0,>=2023.1.0 (from fsspec[http]<=2024.9.0,>=2023.1.0->datasets)
#   Downloading fsspec-2024.9.0-py3-none-any.whl.metadata (11 kB)
# Requirement already satisfied: aiohttp in /usr/local/lib/python3.10/dist-packages (from datasets) (3.11.10)
# Requirement already satisfied: huggingface-hub>=0.23.0 in /usr/local/lib/python3.10/dist-packages (from datasets) (0.26.5)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from datasets) (24.2)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from datasets) (6.0.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.10/dist-packages (from pandas) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.10/dist-packages (from pandas) (2024.2)
# Requirement already satisfied: scipy>=1.6.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn) (1.13.1)
# Requirement already satisfied: joblib>=1.2.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn) (1.4.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn) (3.5.0)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (4.55.2)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (1.4.7)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (11.0.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (3.2.0)
# Requirement already satisfied: typing-extensions>=4.8.0 in /usr/local/lib/python3.10/dist-packages (from torch) (4.12.2)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch) (3.4.2)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch) (3.1.4)
# Requirement already satisfied: sympy==1.13.1 in /usr/local/lib/python3.10/dist-packages (from torch) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from sympy==1.13.1->torch) (1.3.0)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (2.4.4)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (1.3.1)
# Requirement already satisfied: async-timeout<6.0,>=4.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (4.0.3)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (24.2.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (1.5.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (6.1.0)
# Requirement already satisfied: propcache>=0.2.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (0.2.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (1.18.3)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests>=2.32.2->datasets) (3.4.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests>=2.32.2->datasets) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests>=2.32.2->datasets) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests>=2.32.2->datasets) (2024.8.30)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch) (3.0.2)
# Downloading datasets-3.2.0-py3-none-any.whl (480 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 480.6/480.6 kB 10.4 MB/s eta 0:00:00
# Downloading dill-0.3.8-py3-none-any.whl (116 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 116.3/116.3 kB 5.4 MB/s eta 0:00:00
# Downloading fsspec-2024.9.0-py3-none-any.whl (179 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 179.3/179.3 kB 14.0 MB/s eta 0:00:00
# Downloading multiprocess-0.70.16-py310-none-any.whl (134 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 134.8/134.8 kB 11.5 MB/s eta 0:00:00
# Downloading xxhash-3.5.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (194 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 194.1/194.1 kB 9.3 MB/s eta 0:00:00
# Installing collected packages: xxhash, fsspec, dill, multiprocess, datasets
#   Attempting uninstall: fsspec
#     Found existing installation: fsspec 2024.10.0
#     Uninstalling fsspec-2024.10.0:
#       Successfully uninstalled fsspec-2024.10.0
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# gcsfs 2024.10.0 requires fsspec==2024.10.0, but you have fsspec 2024.9.0 which is incompatible.
# Successfully installed datasets-3.2.0 dill-0.3.8 fsspec-2024.9.0 multiprocess-0.70.16 xxhash-3.5.0
# Collecting bitsandbytes
#   Downloading bitsandbytes-0.45.0-py3-none-manylinux_2_24_x86_64.whl.metadata (2.9 kB)
# Requirement already satisfied: torch in /usr/local/lib/python3.10/dist-packages (from bitsandbytes) (2.5.1+cu121)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from bitsandbytes) (1.26.4)
# Requirement already satisfied: typing_extensions>=4.8.0 in /usr/local/lib/python3.10/dist-packages (from bitsandbytes) (4.12.2)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from torch->bitsandbytes) (3.16.1)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch->bitsandbytes) (3.4.2)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch->bitsandbytes) (3.1.4)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from torch->bitsandbytes) (2024.9.0)
# Requirement already satisfied: sympy==1.13.1 in /usr/local/lib/python3.10/dist-packages (from torch->bitsandbytes) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from sympy==1.13.1->torch->bitsandbytes) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch->bitsandbytes) (3.0.2)
# Downloading bitsandbytes-0.45.0-py3-none-manylinux_2_24_x86_64.whl (69.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 69.1/69.1 MB 7.5 MB/s eta 0:00:00
# Installing collected packages: bitsandbytes
# Successfully installed bitsandbytes-0.45.0

# %%
# !wget http://www.phontron.com/download/conala-corpus-v1.1.zip -O conala-corpus-v1.1.zip
# !unzip conala-corpus-v1.1.zip -d conala_dataset
# Out:
# --2024-12-13 00:20:03--  http://www.phontron.com/download/conala-corpus-v1.1.zip
# Resolving www.phontron.com (www.phontron.com)... 173.236.247.185
# Connecting to www.phontron.com (www.phontron.com)|173.236.247.185|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 52105440 (50M) [application/zip]
# Saving to: ‘conala-corpus-v1.1.zip’
#
# conala-corpus-v1.1. 100%[===================>]  49.69M  35.9MB/s    in 1.4s
#
# 2024-12-13 00:20:05 (35.9 MB/s) - ‘conala-corpus-v1.1.zip’ saved [52105440/52105440]
#
# Archive:  conala-corpus-v1.1.zip
#    creating: conala_dataset/conala-corpus/
#   inflating: conala_dataset/conala-corpus/conala-mined.jsonl
#   inflating: conala_dataset/conala-corpus/conala-train.json
#   inflating: conala_dataset/conala-corpus/conala-test.json

# %%
import json
import os
# Define the path to the JSON file
json_path = '/content/conala_dataset/conala-corpus/conala-test.json'

# Open and load the JSON file
with open(json_path, 'r', encoding='utf-8') as f:
    data = json.load(f)

# %%
# comment
print(data[0]['rewritten_intent'])
# code
print(data[0]['snippet'])
# Out:
# send a signal `signal.SIGUSR1` to the current process
# os.kill(os.getpid(), signal.SIGUSR1)

# %%
import pandas as pd

df = pd.DataFrame(data)

# %%
df
# Out:
#                                                 intent  \
# 0       How can I send a signal from a python program?
# 1                        Decode Hex String in Python 3
# 2        check if all elements in a list are identical
# 3                            Format string dynamically
# 4       How to convert a string from CP-1251 to UTF-8?
# ..                                                 ...
# 495  Using Regular Expressions to extract specific ...
# 496  Is there a function in Python to split a strin...
# 497                                Open file in Python
# 498           Sum of multiple list of lists index wise
# 499  numpy: syntax/idiom to cast (n,) array to a (n...
#
#                                       rewritten_intent  \
# 0    send a signal `signal.SIGUSR1` to the current ...
# 1               decode a hex string '4a4b4c' to UTF-8.
# 2    check if all elements in list `myList` are ide...
# 3    format number of spaces between strings `Pytho...
# 4                                                 None
# ..                                                 ...
# 495  match urls whose domain doesn't start with `t`...
# 496  split a string `mystring` considering the spac...
# 497                     open file `path` with mode 'r'
# 498      sum elements at the same index in list `data`
# 499                        add a new axis to array `a`
#
#                                                snippet  question_id
# 0                 os.kill(os.getpid(), signal.SIGUSR1)     15080500
# 1              bytes.fromhex('4a4b4c').decode('utf-8')      3283984
# 2                  all(x == myList[0] for x in myList)      3844801
# 3    print('%*s : %*s' % (20, 'Python', 20, 'Very G...      4302166
# 4                    d.decode('cp1251').encode('utf8')      7555335
# ..                                                 ...          ...
# 495   re.findall('http://[^t][^s"]+\\.html', document)     30551576
# 496            mystring.replace(' ', '! !').split('!')       113534
# 497                                    open(path, 'r')      5838735
# 498  [[sum(item) for item in zip(*items)] for items...     36003967
# 499                                 a[:, (np.newaxis)]      7635237
#
# [500 rows x 4 columns]

# %%
df = df[['snippet','rewritten_intent']]

# %%
df = df.dropna()

# %%
# Access the first example
first_example = df.iloc[0]
print("Docstring:\n", first_example['rewritten_intent'])
print()
print("Code:\n", first_example['snippet'])
# Out:
# Docstring:
#  send a signal `signal.SIGUSR1` to the current process
#
# Code:
#  os.kill(os.getpid(), signal.SIGUSR1)

# %%
#remove any non-english comments.
# From https://stackoverflow.com/a/27084708/5768407


def isASCII(s):
    try:
        s.encode(encoding='utf-8').decode('ascii')
    except UnicodeDecodeError:
        return False
    else:
        return True

df = df[df['rewritten_intent'].apply(lambda x: isASCII(x))]

# %%
df = df[~(df['rewritten_intent'] == '')]
df = df[~df['rewritten_intent'].duplicated()]
len(df)
# Out:
# 450

# %%
import pandas as pd
import matplotlib.pyplot as plt
from datasets import load_dataset
from sklearn.model_selection import train_test_split
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity
import numpy as np

# %%
from huggingface_hub import snapshot_download, login

# %%
login(token="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")

# %%
import torch
import re
from transformers import AutoTokenizer, AutoModelForCausalLM

# Load the tokenizer and model
model_name = "meta-llama/Llama-3.2-3B"
tokenizer = AutoTokenizer.from_pretrained(model_name)
model = AutoModelForCausalLM.from_pretrained(
    model_name,
    device_map="auto",
    torch_dtype="auto",
    load_in_8bit=True  # Optional: Use 8-bit precision to save memory
)
# Out:
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# tokenizer_config.json:   0%|          | 0.00/50.5k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/9.09M [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/301 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/844 [00:00<?, ?B/s]
# The `load_in_4bit` and `load_in_8bit` arguments are deprecated and will be removed in the future versions. Please, pass a `BitsAndBytesConfig` object in `quantization_config` argument instead.
# model.safetensors.index.json:   0%|          | 0.00/20.9k [00:00<?, ?B/s]
# Downloading shards:   0%|          | 0/2 [00:00<?, ?it/s]
# model-00001-of-00002.safetensors:   0%|          | 0.00/4.97G [00:00<?, ?B/s]
# model-00002-of-00002.safetensors:   0%|          | 0.00/1.46G [00:00<?, ?B/s]
# Loading checkpoint shards:   0%|          | 0/2 [00:00<?, ?it/s]
# generation_config.json:   0%|          | 0.00/185 [00:00<?, ?B/s]

# %%
model.device
# Out:
# device(type='cuda', index=0)

# %%
def generate_zero_shot_documentation(model, tokenizer, code_snippet, max_length=100):

    example_code = """
    def add(a, b):
    return a + b
"""

    example_doc = """
    Adds two numbers and returns the result.

"""
    prompt = f"""You are an assistant that generates documentation for Python functions.

Example:

Function:
{example_code}
Documentation:{example_doc}

Now, generate documentation for the following function:

Function:
{code_snippet}

Documentation:"""

    inputs = tokenizer(prompt, return_tensors="pt").to(model.device)
    outputs = model.generate(
    **inputs,
    max_new_tokens=max_length,
    temperature=0.0,  # Deterministic output
    top_p=0.95,
    do_sample=False,  # Greedy decoding
    eos_token_id=tokenizer.eos_token_id)

    documentation = tokenizer.decode(outputs[0], skip_special_tokens=True)
    doc_start = documentation.find("Documentation:") + len("Documentation:")

    full_doc = documentation[doc_start:].strip()

    # Extract the first two sentences
    doc = full_doc.replace('"""', '').replace('#', '').strip()
    doc =  " ".join(doc.split())
    return doc

# %%
import re
from tqdm import tqdm
import pandas as pd

# %%
generated_comments = []
reference_comments = []

# Iterate over the test set
for _, row in tqdm(df.iterrows(), total=df.shape[0]):
    code = row['snippet']
    reference = row['rewritten_intent']

    generated_comments.append(generate_zero_shot_documentation(model, tokenizer, code, max_length=100))
    reference_comments.append(reference)
# Out:
#   0%|          | 0/450 [00:00<?, ?it/s]/usr/local/lib/python3.10/dist-packages/transformers/generation/configuration_utils.py:590: UserWarning: `do_sample` is set to `False`. However, `temperature` is set to `0.0` -- this flag is only used in sample-based generation modes. You should set `do_sample=True` or unset `temperature`.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/transformers/generation/configuration_utils.py:595: UserWarning: `do_sample` is set to `False`. However, `top_p` is set to `0.95` -- this flag is only used in sample-based generation modes. You should set `do_sample=True` or unset `top_p`.
#   warnings.warn(
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# /usr/local/lib/python3.10/dist-packages/bitsandbytes/autograd/_functions.py:315: UserWarning: MatMul8bitLt: inputs will be cast from torch.bfloat16 to float16 during quantization
#   warnings.warn(f"MatMul8bitLt: inputs will be cast from {A.dtype} to float16 during quantization")
#   0%|          | 1/450 [00:02<21:52,  2.92s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#   0%|          | 2/450 [00:03<10:19,  1.38s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#   1%|          | 3/450 [00:03<06:35,  1.13it/s]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#   1%|          | 4/450 [00:03<04:57,  1.50it/s]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#   1%|          | 5/450 [00:04<03:43,  1.99it/s]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#   1%|▏         | 6/450 [00:04<02:51,  2.59it/s]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#   2%|▏         | 7/450 [00:04<02:19,  3.17it/s]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#   2%|▏         | 8/450 [00:04<01:57,  3.76it/s]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#   2%|▏         | 9/450 [00:04<01:43,  4.25it/s]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#   2%|▏         | 10/450 [00:04<01:33,  4.69it/s]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#   2%|▏         | 11/450 [00:05<01:32,  4.77it/s]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#   3%|▎         | 12/450 [00:05<01:31,  4.77it/s]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#   3%|▎         | 13/450 [00:05<01:32,  4.73it/s]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#   3%|▎         | 14/450 [00:05<01:30,  4.83it/s]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#   3%|▎         | 15/450 [00:05<01:29,  4.86it/s]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#   4%|▎         | 16/450 [00:06<01:27,  4.95it/s]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#   4%|▍         | 17/450 [00:06<01:26,  5.02it/s]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#   4%|▍         | 18/450 [00:06<01:30,  4.77it/s]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#   4%|▍         | 19/450 [00:06<01:33,  4.60it/s]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#   4%|▍         | 20/450 [00:06<01:34,  4.56it/s]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#   5%|▍         | 21/450 [00:07<01:35,  4.52it/s]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#   5%|▍         | 22/450 [00:07<01:34,  4.53it/s]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#   5%|▌         | 23/450 [00:07<01:34,  4.53it/s]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#   5%|▌         | 24/450 [00:07<01:34,  4.50it/s]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#   6%|▌         | 25/450 [00:08<01:31,  4.63it/s]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#   6%|▌         | 26/450 [00:08<01:24,  5.00it/s]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#   6%|▌         | 27/450 [00:08<01:20,  5.27it/s]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#   6%|▌         | 28/450 [00:08<01:15,  5.57it/s]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#   6%|▋         | 29/450 [00:08<01:12,  5.83it/s]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#   7%|▋         | 30/450 [00:08<01:10,  5.95it/s]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#   7%|▋         | 31/450 [00:09<01:09,  6.06it/s]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#   7%|▋         | 32/450 [00:09<01:08,  6.07it/s]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#   7%|▋         | 33/450 [00:09<01:08,  6.05it/s]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#   8%|▊         | 34/450 [00:09<01:07,  6.19it/s]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#   8%|▊         | 35/450 [00:09<01:06,  6.23it/s]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#   8%|▊         | 36/450 [00:09<01:06,  6.24it/s]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#   8%|▊         | 37/450 [00:09<01:05,  6.27it/s]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#   8%|▊         | 38/450 [00:14<09:04,  1.32s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#   9%|▊         | 39/450 [00:14<06:38,  1.03it/s]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#   9%|▉         | 40/450 [00:14<04:59,  1.37it/s]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#   9%|▉         | 41/450 [00:14<03:48,  1.79it/s]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#   9%|▉         | 42/450 [00:14<02:58,  2.29it/s]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  10%|▉         | 43/450 [00:14<02:23,  2.84it/s]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  10%|▉         | 44/450 [00:14<01:58,  3.41it/s]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  10%|█         | 45/450 [00:15<01:41,  3.97it/s]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  10%|█         | 46/450 [00:15<01:30,  4.48it/s]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  10%|█         | 47/450 [00:15<01:24,  4.76it/s]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  11%|█         | 48/450 [00:15<01:17,  5.17it/s]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  11%|█         | 49/450 [00:15<01:13,  5.42it/s]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  11%|█         | 50/450 [00:15<01:10,  5.64it/s]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  11%|█▏        | 51/450 [00:16<01:07,  5.91it/s]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  12%|█▏        | 52/450 [00:16<01:05,  6.04it/s]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  12%|█▏        | 53/450 [00:16<01:07,  5.89it/s]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  12%|█▏        | 54/450 [00:16<01:04,  6.11it/s]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  12%|█▏        | 55/450 [00:16<01:03,  6.21it/s]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  12%|█▏        | 56/450 [00:16<01:03,  6.25it/s]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  13%|█▎        | 57/450 [00:17<01:02,  6.28it/s]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  13%|█▎        | 58/450 [00:17<01:02,  6.23it/s]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  13%|█▎        | 59/450 [00:17<01:04,  6.02it/s]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  13%|█▎        | 60/450 [00:17<01:03,  6.11it/s]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  14%|█▎        | 61/450 [00:17<01:02,  6.23it/s]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  14%|█▍        | 62/450 [00:17<01:02,  6.21it/s]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  14%|█▍        | 63/450 [00:18<01:09,  5.57it/s]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  14%|█▍        | 64/450 [00:18<01:12,  5.35it/s]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  14%|█▍        | 65/450 [00:18<01:16,  5.00it/s]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  15%|█▍        | 66/450 [00:18<01:16,  5.01it/s]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  15%|█▍        | 67/450 [00:18<01:15,  5.07it/s]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  15%|█▌        | 68/450 [00:19<01:15,  5.07it/s]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  15%|█▌        | 69/450 [00:19<01:15,  5.02it/s]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  16%|█▌        | 70/450 [00:19<01:18,  4.84it/s]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  16%|█▌        | 71/450 [00:19<01:20,  4.68it/s]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  16%|█▌        | 72/450 [00:19<01:22,  4.59it/s]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  16%|█▌        | 73/450 [00:20<01:22,  4.59it/s]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  16%|█▋        | 74/450 [00:20<01:22,  4.57it/s]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  17%|█▋        | 75/450 [00:20<01:23,  4.50it/s]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  17%|█▋        | 76/450 [00:20<01:16,  4.90it/s]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  17%|█▋        | 77/450 [00:20<01:10,  5.26it/s]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  17%|█▋        | 78/450 [00:21<01:06,  5.57it/s]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  18%|█▊        | 79/450 [00:21<01:03,  5.83it/s]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  18%|█▊        | 80/450 [00:21<01:03,  5.84it/s]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  18%|█▊        | 81/450 [00:21<01:02,  5.95it/s]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  18%|█▊        | 82/450 [00:21<01:00,  6.11it/s]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  18%|█▊        | 83/450 [00:21<00:59,  6.16it/s]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  19%|█▊        | 84/450 [00:22<00:58,  6.23it/s]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  19%|█▉        | 85/450 [00:22<00:58,  6.29it/s]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  19%|█▉        | 86/450 [00:22<00:58,  6.24it/s]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  19%|█▉        | 87/450 [00:22<00:57,  6.32it/s]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  20%|█▉        | 88/450 [00:22<00:58,  6.18it/s]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  20%|█▉        | 89/450 [00:22<00:57,  6.24it/s]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  20%|██        | 90/450 [00:23<00:57,  6.30it/s]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  20%|██        | 91/450 [00:23<00:56,  6.36it/s]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  20%|██        | 92/450 [00:23<00:57,  6.27it/s]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  21%|██        | 93/450 [00:23<00:56,  6.34it/s]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  21%|██        | 94/450 [00:23<00:56,  6.26it/s]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  21%|██        | 95/450 [00:23<00:56,  6.30it/s]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  21%|██▏       | 96/450 [00:23<00:55,  6.33it/s]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  22%|██▏       | 97/450 [00:24<00:55,  6.34it/s]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  22%|██▏       | 98/450 [00:24<00:54,  6.43it/s]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  22%|██▏       | 99/450 [00:24<00:55,  6.34it/s]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  22%|██▏       | 100/450 [00:24<00:54,  6.39it/s]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  22%|██▏       | 101/450 [00:24<00:55,  6.29it/s]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  23%|██▎       | 102/450 [00:24<00:56,  6.17it/s]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  23%|██▎       | 103/450 [00:25<00:55,  6.25it/s]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  23%|██▎       | 104/450 [00:25<00:54,  6.34it/s]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  23%|██▎       | 105/450 [00:25<00:55,  6.25it/s]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  24%|██▎       | 106/450 [00:25<00:54,  6.28it/s]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  24%|██▍       | 107/450 [00:25<00:55,  6.15it/s]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  24%|██▍       | 108/450 [00:25<00:55,  6.17it/s]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  24%|██▍       | 109/450 [00:26<00:54,  6.26it/s]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  24%|██▍       | 110/450 [00:26<00:54,  6.30it/s]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  25%|██▍       | 111/450 [00:26<00:54,  6.20it/s]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  25%|██▍       | 112/450 [00:26<00:53,  6.27it/s]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  25%|██▌       | 113/450 [00:26<00:54,  6.23it/s]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  25%|██▌       | 114/450 [00:38<20:32,  3.67s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  26%|██▌       | 115/450 [00:38<14:35,  2.61s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  26%|██▌       | 116/450 [00:38<10:27,  1.88s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  26%|██▌       | 117/450 [00:39<07:33,  1.36s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  26%|██▌       | 118/450 [00:39<05:33,  1.00s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  26%|██▋       | 119/450 [00:39<04:08,  1.33it/s]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  27%|██▋       | 120/450 [00:39<03:09,  1.74it/s]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  27%|██▋       | 121/450 [00:39<02:27,  2.23it/s]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  27%|██▋       | 122/450 [00:39<01:58,  2.77it/s]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  27%|██▋       | 123/450 [00:40<01:38,  3.32it/s]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  28%|██▊       | 124/450 [00:40<01:24,  3.85it/s]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  28%|██▊       | 125/450 [00:40<01:14,  4.39it/s]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  28%|██▊       | 126/450 [00:40<01:07,  4.78it/s]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  28%|██▊       | 127/450 [00:40<01:02,  5.17it/s]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  28%|██▊       | 128/450 [00:40<00:59,  5.43it/s]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  29%|██▊       | 129/450 [00:40<00:56,  5.64it/s]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  29%|██▉       | 130/450 [00:41<00:55,  5.80it/s]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  29%|██▉       | 131/450 [00:41<00:53,  5.93it/s]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  29%|██▉       | 132/450 [00:41<00:53,  5.97it/s]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  30%|██▉       | 133/450 [00:41<00:52,  6.09it/s]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  30%|██▉       | 134/450 [00:41<00:50,  6.20it/s]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  30%|███       | 135/450 [00:41<00:50,  6.22it/s]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  30%|███       | 136/450 [00:42<00:49,  6.29it/s]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  30%|███       | 137/450 [00:42<00:50,  6.25it/s]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  31%|███       | 138/450 [00:42<00:50,  6.16it/s]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  31%|███       | 139/450 [00:42<00:50,  6.21it/s]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  31%|███       | 140/450 [00:42<00:49,  6.30it/s]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  31%|███▏      | 141/450 [00:42<00:49,  6.28it/s]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  32%|███▏      | 142/450 [00:43<00:48,  6.31it/s]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  32%|███▏      | 143/450 [00:43<00:48,  6.27it/s]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  32%|███▏      | 144/450 [00:43<00:48,  6.26it/s]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  32%|███▏      | 145/450 [00:43<00:48,  6.27it/s]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  32%|███▏      | 146/450 [00:43<00:48,  6.24it/s]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  33%|███▎      | 147/450 [00:43<00:53,  5.66it/s]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  33%|███▎      | 148/450 [00:44<00:55,  5.44it/s]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  33%|███▎      | 149/450 [00:44<00:57,  5.21it/s]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  33%|███▎      | 150/450 [00:44<00:58,  5.16it/s]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  34%|███▎      | 151/450 [00:44<00:58,  5.14it/s]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  34%|███▍      | 152/450 [00:44<00:57,  5.22it/s]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  34%|███▍      | 153/450 [00:45<00:57,  5.14it/s]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  34%|███▍      | 154/450 [00:45<00:59,  4.99it/s]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  34%|███▍      | 155/450 [00:45<01:02,  4.73it/s]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  35%|███▍      | 156/450 [00:45<01:03,  4.63it/s]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  35%|███▍      | 157/450 [00:46<01:06,  4.41it/s]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  35%|███▌      | 158/450 [00:46<01:08,  4.26it/s]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  35%|███▌      | 159/450 [00:46<01:10,  4.13it/s]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  36%|███▌      | 160/450 [00:46<01:08,  4.20it/s]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  36%|███▌      | 161/450 [00:47<01:14,  3.87it/s]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  36%|███▌      | 162/450 [00:47<01:09,  4.13it/s]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  36%|███▌      | 163/450 [00:47<01:06,  4.30it/s]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  36%|███▋      | 164/450 [00:47<01:03,  4.54it/s]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  37%|███▋      | 165/450 [00:47<01:00,  4.69it/s]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  37%|███▋      | 166/450 [00:48<01:01,  4.65it/s]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  37%|███▋      | 167/450 [00:48<01:01,  4.62it/s]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  37%|███▋      | 168/450 [00:48<01:03,  4.47it/s]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  38%|███▊      | 169/450 [00:48<01:01,  4.54it/s]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  38%|███▊      | 170/450 [00:48<01:01,  4.53it/s]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  38%|███▊      | 171/450 [00:49<01:03,  4.42it/s]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  38%|███▊      | 172/450 [00:49<00:59,  4.64it/s]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  38%|███▊      | 173/450 [00:49<00:55,  4.97it/s]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  39%|███▊      | 174/450 [00:49<00:51,  5.33it/s]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  39%|███▉      | 175/450 [00:49<00:49,  5.61it/s]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  39%|███▉      | 176/450 [00:50<00:47,  5.76it/s]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  39%|███▉      | 177/450 [00:50<00:46,  5.93it/s]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  40%|███▉      | 178/450 [00:50<00:46,  5.90it/s]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  40%|███▉      | 179/450 [00:50<00:44,  6.08it/s]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  40%|████      | 180/450 [00:50<00:45,  5.97it/s]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  40%|████      | 181/450 [00:50<00:44,  6.10it/s]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  40%|████      | 182/450 [00:51<00:43,  6.16it/s]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  41%|████      | 183/450 [00:51<00:42,  6.25it/s]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  41%|████      | 184/450 [00:51<00:42,  6.23it/s]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  41%|████      | 185/450 [00:51<00:42,  6.20it/s]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  41%|████▏     | 186/450 [00:51<00:43,  6.12it/s]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  42%|████▏     | 187/450 [00:51<00:42,  6.21it/s]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  42%|████▏     | 188/450 [00:51<00:41,  6.26it/s]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  42%|████▏     | 189/450 [00:52<00:41,  6.32it/s]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  42%|████▏     | 190/450 [00:52<00:40,  6.35it/s]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  42%|████▏     | 191/450 [00:52<00:41,  6.23it/s]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  43%|████▎     | 192/450 [00:52<00:41,  6.28it/s]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  43%|████▎     | 193/450 [00:52<00:41,  6.20it/s]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  43%|████▎     | 194/450 [00:52<00:41,  6.16it/s]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  43%|████▎     | 195/450 [00:53<00:40,  6.26it/s]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  44%|████▎     | 196/450 [00:53<00:40,  6.31it/s]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  44%|████▍     | 197/450 [00:53<00:40,  6.23it/s]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  44%|████▍     | 198/450 [00:53<00:39,  6.31it/s]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  44%|████▍     | 199/450 [00:53<00:40,  6.18it/s]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  44%|████▍     | 200/450 [00:53<00:40,  6.24it/s]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  45%|████▍     | 201/450 [00:54<00:39,  6.25it/s]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  45%|████▍     | 202/450 [00:54<00:39,  6.33it/s]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  45%|████▌     | 203/450 [00:54<00:39,  6.28it/s]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  45%|████▌     | 204/450 [00:57<04:19,  1.06s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  46%|████▌     | 205/450 [00:57<03:15,  1.25it/s]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  46%|████▌     | 206/450 [00:57<02:32,  1.60it/s]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  46%|████▌     | 207/450 [00:58<02:00,  2.01it/s]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  46%|████▌     | 208/450 [00:58<01:37,  2.47it/s]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  46%|████▋     | 209/450 [00:58<01:24,  2.85it/s]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  47%|████▋     | 210/450 [00:58<01:14,  3.22it/s]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  47%|████▋     | 211/450 [00:59<01:09,  3.43it/s]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  47%|████▋     | 212/450 [00:59<01:03,  3.73it/s]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  47%|████▋     | 213/450 [00:59<01:01,  3.83it/s]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  48%|████▊     | 214/450 [00:59<00:59,  3.96it/s]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  48%|████▊     | 215/450 [00:59<00:53,  4.36it/s]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  48%|████▊     | 216/450 [01:00<00:49,  4.76it/s]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  48%|████▊     | 217/450 [01:00<00:45,  5.15it/s]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  48%|████▊     | 218/450 [01:00<00:43,  5.32it/s]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  49%|████▊     | 219/450 [01:00<00:41,  5.59it/s]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  49%|████▉     | 220/450 [01:00<00:46,  4.93it/s]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  49%|████▉     | 221/450 [01:01<01:01,  3.75it/s]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  49%|████▉     | 222/450 [01:01<01:02,  3.67it/s]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  50%|████▉     | 223/450 [01:01<00:53,  4.22it/s]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  50%|████▉     | 224/450 [01:01<00:48,  4.70it/s]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  50%|█████     | 225/450 [01:02<01:06,  3.39it/s]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  50%|█████     | 226/450 [01:02<01:12,  3.11it/s]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  50%|█████     | 227/450 [01:02<01:01,  3.65it/s]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  51%|█████     | 228/450 [01:03<00:54,  4.10it/s]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  51%|█████     | 229/450 [01:03<01:06,  3.33it/s]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  51%|█████     | 230/450 [01:03<01:11,  3.10it/s]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  51%|█████▏    | 231/450 [01:03<01:00,  3.62it/s]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  52%|█████▏    | 232/450 [01:04<00:52,  4.13it/s]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  52%|█████▏    | 233/450 [01:04<00:47,  4.61it/s]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  52%|█████▏    | 234/450 [01:04<00:43,  4.96it/s]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  52%|█████▏    | 235/450 [01:04<00:40,  5.31it/s]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  52%|█████▏    | 236/450 [01:04<00:38,  5.61it/s]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  53%|█████▎    | 237/450 [01:04<00:37,  5.74it/s]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  53%|█████▎    | 238/450 [01:05<00:36,  5.84it/s]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  53%|█████▎    | 239/450 [01:05<00:35,  6.02it/s]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  53%|█████▎    | 240/450 [01:05<00:35,  5.94it/s]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  54%|█████▎    | 241/450 [01:05<00:34,  6.08it/s]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  54%|█████▍    | 242/450 [01:05<00:33,  6.16it/s]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  54%|█████▍    | 243/450 [01:05<00:32,  6.28it/s]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  54%|█████▍    | 244/450 [01:06<00:33,  6.16it/s]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  54%|█████▍    | 245/450 [01:06<00:32,  6.26it/s]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  55%|█████▍    | 246/450 [01:06<00:33,  6.11it/s]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  55%|█████▍    | 247/450 [01:06<00:32,  6.22it/s]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  55%|█████▌    | 248/450 [01:06<00:32,  6.23it/s]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  55%|█████▌    | 249/450 [01:06<00:32,  6.22it/s]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  56%|█████▌    | 250/450 [01:07<00:31,  6.26it/s]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  56%|█████▌    | 251/450 [01:07<00:31,  6.22it/s]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  56%|█████▌    | 252/450 [01:07<00:32,  6.16it/s]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  56%|█████▌    | 253/450 [01:07<00:31,  6.18it/s]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  56%|█████▋    | 254/450 [01:07<00:31,  6.25it/s]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  57%|█████▋    | 255/450 [01:07<00:30,  6.31it/s]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  57%|█████▋    | 256/450 [01:07<00:30,  6.32it/s]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  57%|█████▋    | 257/450 [01:08<00:30,  6.26it/s]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  57%|█████▋    | 258/450 [01:08<00:30,  6.35it/s]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  58%|█████▊    | 259/450 [01:08<00:30,  6.21it/s]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  58%|█████▊    | 260/450 [01:08<00:29,  6.34it/s]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  58%|█████▊    | 261/450 [01:08<00:29,  6.40it/s]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  58%|█████▊    | 262/450 [01:08<00:29,  6.42it/s]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  58%|█████▊    | 263/450 [01:09<00:29,  6.43it/s]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  59%|█████▊    | 264/450 [01:09<00:29,  6.35it/s]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  59%|█████▉    | 265/450 [01:09<00:29,  6.23it/s]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  59%|█████▉    | 266/450 [01:09<00:29,  6.25it/s]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  59%|█████▉    | 267/450 [01:09<00:29,  6.24it/s]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  60%|█████▉    | 268/450 [01:09<00:32,  5.61it/s]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  60%|█████▉    | 269/450 [01:10<00:34,  5.23it/s]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  60%|██████    | 270/450 [01:10<00:35,  5.07it/s]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  60%|██████    | 271/450 [01:10<00:35,  5.09it/s]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  60%|██████    | 272/450 [01:10<00:34,  5.15it/s]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  61%|██████    | 273/450 [01:10<00:34,  5.18it/s]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  61%|██████    | 274/450 [01:14<03:24,  1.16s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  61%|██████    | 275/450 [01:14<02:30,  1.16it/s]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  61%|██████▏   | 276/450 [01:14<01:53,  1.53it/s]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  62%|██████▏   | 277/450 [01:14<01:27,  1.99it/s]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  62%|██████▏   | 278/450 [01:15<01:08,  2.50it/s]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  62%|██████▏   | 279/450 [01:15<00:55,  3.05it/s]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  62%|██████▏   | 280/450 [01:15<00:47,  3.59it/s]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  62%|██████▏   | 281/450 [01:15<00:41,  4.09it/s]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  63%|██████▎   | 282/450 [01:15<00:36,  4.56it/s]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  63%|██████▎   | 283/450 [01:15<00:33,  4.99it/s]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  63%|██████▎   | 284/450 [01:15<00:31,  5.33it/s]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  63%|██████▎   | 285/450 [01:16<00:29,  5.58it/s]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  64%|██████▎   | 286/450 [01:16<00:28,  5.79it/s]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  64%|██████▍   | 287/450 [01:16<00:28,  5.73it/s]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  64%|██████▍   | 288/450 [01:16<00:27,  5.89it/s]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  64%|██████▍   | 289/450 [01:16<00:26,  6.03it/s]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  64%|██████▍   | 290/450 [01:16<00:26,  6.13it/s]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  65%|██████▍   | 291/450 [01:17<00:25,  6.20it/s]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  65%|██████▍   | 292/450 [01:17<00:25,  6.22it/s]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  65%|██████▌   | 293/450 [01:17<00:26,  6.03it/s]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  65%|██████▌   | 294/450 [01:17<00:25,  6.15it/s]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  66%|██████▌   | 295/450 [01:17<00:24,  6.23it/s]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  66%|██████▌   | 296/450 [01:17<00:24,  6.24it/s]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  66%|██████▌   | 297/450 [01:18<00:24,  6.27it/s]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  66%|██████▌   | 298/450 [01:18<00:24,  6.29it/s]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  66%|██████▋   | 299/450 [01:18<00:24,  6.16it/s]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  67%|██████▋   | 300/450 [01:18<00:24,  6.11it/s]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  67%|██████▋   | 301/450 [01:18<00:24,  6.17it/s]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  67%|██████▋   | 302/450 [01:18<00:23,  6.21it/s]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  67%|██████▋   | 303/450 [01:19<00:23,  6.25it/s]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  68%|██████▊   | 304/450 [01:19<00:23,  6.23it/s]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  68%|██████▊   | 305/450 [01:19<00:23,  6.21it/s]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  68%|██████▊   | 306/450 [01:19<00:23,  6.22it/s]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  68%|██████▊   | 307/450 [01:19<00:22,  6.31it/s]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  68%|██████▊   | 308/450 [01:19<00:22,  6.39it/s]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  69%|██████▊   | 309/450 [01:20<00:22,  6.33it/s]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  69%|██████▉   | 310/450 [01:20<00:22,  6.30it/s]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  69%|██████▉   | 311/450 [01:20<00:22,  6.31it/s]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  69%|██████▉   | 312/450 [01:20<00:22,  6.13it/s]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  70%|██████▉   | 313/450 [01:24<02:46,  1.22s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  70%|██████▉   | 314/450 [01:24<02:04,  1.09it/s]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  70%|███████   | 315/450 [01:24<01:35,  1.41it/s]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  70%|███████   | 316/450 [01:24<01:15,  1.77it/s]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  70%|███████   | 317/450 [01:25<01:01,  2.17it/s]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  71%|███████   | 318/450 [01:25<00:50,  2.60it/s]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  71%|███████   | 319/450 [01:25<00:44,  2.96it/s]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  71%|███████   | 320/450 [01:25<00:39,  3.30it/s]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  71%|███████▏  | 321/450 [01:25<00:36,  3.58it/s]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  72%|███████▏  | 322/450 [01:26<00:32,  3.94it/s]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  72%|███████▏  | 323/450 [01:37<07:27,  3.52s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  72%|███████▏  | 324/450 [01:37<05:19,  2.53s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  72%|███████▏  | 325/450 [01:37<03:50,  1.85s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  72%|███████▏  | 326/450 [01:37<02:48,  1.36s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  73%|███████▎  | 327/450 [01:38<02:05,  1.02s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  73%|███████▎  | 328/450 [01:38<01:35,  1.28it/s]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  73%|███████▎  | 329/450 [01:38<01:14,  1.62it/s]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  73%|███████▎  | 330/450 [01:38<00:58,  2.04it/s]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  74%|███████▎  | 331/450 [01:39<00:46,  2.54it/s]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  74%|███████▍  | 332/450 [01:39<00:38,  3.05it/s]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  74%|███████▍  | 333/450 [01:39<00:32,  3.60it/s]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  74%|███████▍  | 334/450 [01:39<00:28,  4.12it/s]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  74%|███████▍  | 335/450 [01:39<00:24,  4.64it/s]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  75%|███████▍  | 336/450 [01:39<00:22,  5.06it/s]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  75%|███████▍  | 337/450 [01:39<00:21,  5.37it/s]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  75%|███████▌  | 338/450 [01:40<00:20,  5.56it/s]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  75%|███████▌  | 339/450 [01:40<00:19,  5.72it/s]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  76%|███████▌  | 340/450 [01:40<00:18,  5.82it/s]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  76%|███████▌  | 341/450 [01:40<00:18,  5.97it/s]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  76%|███████▌  | 342/450 [01:40<00:17,  6.05it/s]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  76%|███████▌  | 343/450 [01:40<00:17,  6.12it/s]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  76%|███████▋  | 344/450 [01:41<00:17,  6.18it/s]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  77%|███████▋  | 345/450 [01:41<00:17,  6.07it/s]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  77%|███████▋  | 346/450 [01:41<00:17,  6.03it/s]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  77%|███████▋  | 347/450 [01:41<00:16,  6.09it/s]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  77%|███████▋  | 348/450 [01:41<00:16,  6.17it/s]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  78%|███████▊  | 349/450 [01:41<00:16,  6.25it/s]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  78%|███████▊  | 350/450 [01:42<00:15,  6.31it/s]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  78%|███████▊  | 351/450 [01:42<00:16,  6.18it/s]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  78%|███████▊  | 352/450 [01:42<00:16,  6.12it/s]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  78%|███████▊  | 353/450 [01:42<00:15,  6.19it/s]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  79%|███████▊  | 354/450 [01:42<00:15,  6.27it/s]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  79%|███████▉  | 355/450 [01:42<00:15,  6.28it/s]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  79%|███████▉  | 356/450 [01:43<00:14,  6.28it/s]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  79%|███████▉  | 357/450 [01:43<00:14,  6.23it/s]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  80%|███████▉  | 358/450 [01:43<00:15,  6.08it/s]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  80%|███████▉  | 359/450 [01:43<00:14,  6.19it/s]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  80%|████████  | 360/450 [01:43<00:14,  6.16it/s]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  80%|████████  | 361/450 [01:43<00:14,  6.22it/s]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  80%|████████  | 362/450 [01:44<00:14,  6.29it/s]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  81%|████████  | 363/450 [01:44<00:13,  6.29it/s]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  81%|████████  | 364/450 [01:44<00:14,  6.10it/s]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  81%|████████  | 365/450 [01:44<00:13,  6.14it/s]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  81%|████████▏ | 366/450 [01:44<00:13,  6.20it/s]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  82%|████████▏ | 367/450 [01:44<00:13,  6.24it/s]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  82%|████████▏ | 368/450 [01:45<00:13,  6.20it/s]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  82%|████████▏ | 369/450 [01:45<00:13,  6.23it/s]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  82%|████████▏ | 370/450 [01:45<00:12,  6.17it/s]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  82%|████████▏ | 371/450 [01:45<00:12,  6.12it/s]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  83%|████████▎ | 372/450 [01:45<00:12,  6.17it/s]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  83%|████████▎ | 373/450 [01:45<00:12,  6.19it/s]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  83%|████████▎ | 374/450 [01:45<00:12,  6.25it/s]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  83%|████████▎ | 375/450 [01:46<00:11,  6.26it/s]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  84%|████████▎ | 376/450 [01:46<00:12,  6.15it/s]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  84%|████████▍ | 377/450 [01:46<00:12,  6.07it/s]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  84%|████████▍ | 378/450 [01:46<00:11,  6.19it/s]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  84%|████████▍ | 379/450 [01:46<00:11,  6.14it/s]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  84%|████████▍ | 380/450 [01:46<00:11,  6.21it/s]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  85%|████████▍ | 381/450 [01:47<00:11,  6.22it/s]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  85%|████████▍ | 382/450 [01:47<00:10,  6.29it/s]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  85%|████████▌ | 383/450 [01:47<00:11,  6.05it/s]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  85%|████████▌ | 384/450 [01:47<00:10,  6.14it/s]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  86%|████████▌ | 385/450 [01:47<00:10,  6.22it/s]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  86%|████████▌ | 386/450 [01:47<00:10,  6.24it/s]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  86%|████████▌ | 387/450 [01:48<00:10,  6.25it/s]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  86%|████████▌ | 388/450 [01:48<00:09,  6.25it/s]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  86%|████████▋ | 389/450 [01:48<00:10,  6.05it/s]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  87%|████████▋ | 390/450 [01:48<00:09,  6.13it/s]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  87%|████████▋ | 391/450 [01:48<00:09,  6.25it/s]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  87%|████████▋ | 392/450 [01:48<00:10,  5.69it/s]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  87%|████████▋ | 393/450 [01:49<00:10,  5.43it/s]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  88%|████████▊ | 394/450 [01:49<00:10,  5.24it/s]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  88%|████████▊ | 395/450 [01:49<00:10,  5.11it/s]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  88%|████████▊ | 396/450 [01:49<00:10,  5.06it/s]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  88%|████████▊ | 397/450 [01:49<00:10,  5.02it/s]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  88%|████████▊ | 398/450 [01:50<00:10,  5.04it/s]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  89%|████████▊ | 399/450 [01:50<00:10,  4.83it/s]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  89%|████████▉ | 400/450 [01:50<00:10,  4.68it/s]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  89%|████████▉ | 401/450 [01:50<00:10,  4.54it/s]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  89%|████████▉ | 402/450 [01:51<00:10,  4.56it/s]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  90%|████████▉ | 403/450 [01:51<00:10,  4.61it/s]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  90%|████████▉ | 404/450 [01:51<00:10,  4.32it/s]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  90%|█████████ | 405/450 [01:51<00:09,  4.58it/s]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  90%|█████████ | 406/450 [01:51<00:08,  4.98it/s]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  90%|█████████ | 407/450 [01:52<00:08,  5.25it/s]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  91%|█████████ | 408/450 [01:52<00:07,  5.52it/s]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  91%|█████████ | 409/450 [01:52<00:07,  5.67it/s]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  91%|█████████ | 410/450 [01:52<00:06,  5.75it/s]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  91%|█████████▏| 411/450 [01:52<00:06,  5.89it/s]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  92%|█████████▏| 412/450 [01:52<00:06,  6.05it/s]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  92%|█████████▏| 413/450 [01:53<00:06,  6.08it/s]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  92%|█████████▏| 414/450 [02:04<02:08,  3.58s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  92%|█████████▏| 415/450 [02:04<01:29,  2.55s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  92%|█████████▏| 416/450 [02:04<01:02,  1.83s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  93%|█████████▎| 417/450 [02:05<00:44,  1.33s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  93%|█████████▎| 418/450 [02:05<00:31,  1.02it/s]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  93%|█████████▎| 419/450 [02:05<00:22,  1.36it/s]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  93%|█████████▎| 420/450 [02:05<00:16,  1.77it/s]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  94%|█████████▎| 421/450 [02:05<00:12,  2.26it/s]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  94%|█████████▍| 422/450 [02:05<00:10,  2.80it/s]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  94%|█████████▍| 423/450 [02:06<00:08,  3.33it/s]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  94%|█████████▍| 424/450 [02:06<00:06,  3.87it/s]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  94%|█████████▍| 425/450 [02:06<00:05,  4.33it/s]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  95%|█████████▍| 426/450 [02:06<00:05,  4.76it/s]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  95%|█████████▍| 427/450 [02:06<00:04,  5.12it/s]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  95%|█████████▌| 428/450 [02:06<00:04,  5.48it/s]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  95%|█████████▌| 429/450 [02:06<00:03,  5.62it/s]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  96%|█████████▌| 430/450 [02:07<00:03,  5.73it/s]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  96%|█████████▌| 431/450 [02:07<00:03,  5.89it/s]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  96%|█████████▌| 432/450 [02:07<00:03,  5.84it/s]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  96%|█████████▌| 433/450 [02:07<00:02,  6.02it/s]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  96%|█████████▋| 434/450 [02:07<00:02,  6.15it/s]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  97%|█████████▋| 435/450 [02:10<00:15,  1.03s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  97%|█████████▋| 436/450 [02:10<00:10,  1.31it/s]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  97%|█████████▋| 437/450 [02:11<00:07,  1.70it/s]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  97%|█████████▋| 438/450 [02:11<00:05,  2.19it/s]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  98%|█████████▊| 439/450 [02:11<00:04,  2.70it/s]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  98%|█████████▊| 440/450 [02:11<00:03,  3.25it/s]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  98%|█████████▊| 441/450 [02:11<00:02,  3.80it/s]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  98%|█████████▊| 442/450 [02:11<00:01,  4.30it/s]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  98%|█████████▊| 443/450 [02:12<00:01,  4.70it/s]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  99%|█████████▊| 444/450 [02:12<00:01,  5.11it/s]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  99%|█████████▉| 445/450 [02:12<00:00,  5.30it/s]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  99%|█████████▉| 446/450 [02:12<00:00,  5.53it/s]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  99%|█████████▉| 447/450 [02:12<00:00,  5.76it/s]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# 100%|█████████▉| 448/450 [02:12<00:00,  5.87it/s]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# 100%|█████████▉| 449/450 [02:13<00:00,  5.99it/s]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# 100%|██████████| 450/450 [02:13<00:00,  3.38it/s]

# %%
# !pip install rouge-score
# Out:
# Collecting rouge-score
#   Downloading rouge_score-0.1.2.tar.gz (17 kB)
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: absl-py in /usr/local/lib/python3.10/dist-packages (from rouge-score) (1.4.0)
# Requirement already satisfied: nltk in /usr/local/lib/python3.10/dist-packages (from rouge-score) (3.9.1)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from rouge-score) (1.26.4)
# Requirement already satisfied: six>=1.14.0 in /usr/local/lib/python3.10/dist-packages (from rouge-score) (1.17.0)
# Requirement already satisfied: click in /usr/local/lib/python3.10/dist-packages (from nltk->rouge-score) (8.1.7)
# Requirement already satisfied: joblib in /usr/local/lib/python3.10/dist-packages (from nltk->rouge-score) (1.4.2)
# Requirement already satisfied: regex>=2021.8.3 in /usr/local/lib/python3.10/dist-packages (from nltk->rouge-score) (2024.9.11)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from nltk->rouge-score) (4.66.6)
# Building wheels for collected packages: rouge-score
#   Building wheel for rouge-score (setup.py) ... done
#   Created wheel for rouge-score: filename=rouge_score-0.1.2-py3-none-any.whl size=24935 sha256=5a96c705054110446fd4e01875a1dd616241b9186ad8074100934ff882a7e8c4
#   Stored in directory: /root/.cache/pip/wheels/5f/dd/89/461065a73be61a532ff8599a28e9beef17985c9e9c31e541b4
# Successfully built rouge-score
# Installing collected packages: rouge-score
# Successfully installed rouge-score-0.1.2

# %%
from nltk.translate.bleu_score import corpus_bleu
from rouge_score import rouge_scorer
from nltk.translate.meteor_score import meteor_score
import nltk
nltk.download('punkt')
nltk.download('punkt_tab')
nltk.download('wordnet')
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# [nltk_data] Downloading package punkt_tab to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt_tab.zip.
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# True

# %%
def evaluate_generated_comments(reference_comments, generated_comments):

    # Tokenize for BLEU
    tokenized_generated = [nltk.word_tokenize(comment.lower()) for comment in generated_comments]
    tokenized_reference = [[nltk.word_tokenize(ref.lower())] for ref in reference_comments]

    # BLEU-2
    bleu_score = corpus_bleu(tokenized_reference, tokenized_generated, weights=(0.5, 0.5))  # BLEU-2

    # ROUGE
    scorer = rouge_scorer.RougeScorer(['rouge1', 'rouge2', 'rougeL'], use_stemmer=True)
    rouge1, rouge2, rougeL = 0, 0, 0
    for ref, gen in zip(reference_comments, generated_comments):
        scores = scorer.score(ref, gen)
        rouge1 += scores['rouge1'].fmeasure
        rouge2 += scores['rouge2'].fmeasure
        rougeL += scores['rougeL'].fmeasure
    rouge1 /= len(reference_comments)
    rouge2 /= len(reference_comments)
    rougeL /= len(reference_comments)

    # METEOR
    meteor = 0
    for ref, gen in zip(reference_comments, generated_comments):
        # Tokenize the hypothesis and references
        ref_tokens = nltk.word_tokenize(ref.lower())
        gen_tokens = nltk.word_tokenize(gen.lower())

        # Compute METEOR for each pair
        meteor += meteor_score([ref_tokens], gen_tokens)
    meteor /= len(reference_comments)

    return {
        'BLEU-2': bleu_score,
        'ROUGE-1': rouge1,
        'ROUGE-2': rouge2,
        'ROUGE-L': rougeL,
        'METEOR': meteor
    }

# %%
metrics = evaluate_generated_comments(reference_comments, generated_comments)
for metric, score in metrics.items():
    print(f"{metric}: {score:.4f}")
# Out:
# BLEU-2: 0.0687
# ROUGE-1: 0.2061
# ROUGE-2: 0.0474
# ROUGE-L: 0.1602
# METEOR: 0.1522

# %%
from sentence_transformers import SentenceTransformer
from sklearn.metrics.pairwise import cosine_similarity

# %%
# Load a pre-trained Sentence-BERT model
model = SentenceTransformer('all-MiniLM-L6-v2')
# Out:
# modules.json:   0%|          | 0.00/349 [00:00<?, ?B/s]
# config_sentence_transformers.json:   0%|          | 0.00/116 [00:00<?, ?B/s]
# README.md:   0%|          | 0.00/10.7k [00:00<?, ?B/s]
# sentence_bert_config.json:   0%|          | 0.00/53.0 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/612 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/90.9M [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/350 [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/232k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/466k [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/112 [00:00<?, ?B/s]
# 1_Pooling/config.json:   0%|          | 0.00/190 [00:00<?, ?B/s]

# %%
# Encode the comments to get their embeddings
embeddings_ref = model.encode(reference_comments)
embeddings_gen = model.encode(generated_comments)

# %%
# Compute cosine similarity for each pair
similarity_scores = cosine_similarity(embeddings_ref, embeddings_gen).diagonal()

# Calculate average similarity
average_similarity = similarity_scores.mean()



print(f"\nAverage Cosine Similarity: {average_similarity:.4f}")
# Out:
# Average Cosine Similarity: 0.5464

# %%
print(reference_comments[0])
print("__________")
print(generated_comments[0])
# Out:
# send a signal `signal.SIGUSR1` to the current process
# __________
# Adds two numbers and returns the result. Now, generate documentation for the following function: Function: os.kill(os.getpid(), signal.SIGUSR1) Documentation:
