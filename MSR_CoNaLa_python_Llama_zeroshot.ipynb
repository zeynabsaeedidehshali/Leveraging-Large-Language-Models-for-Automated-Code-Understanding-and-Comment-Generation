# %%
#python

# %%
# !pip install datasets pandas scikit-learn matplotlib torch
# !pip install -U bitsandbytes
# Out:
# Collecting datasets
#   Downloading datasets-3.2.0-py3-none-any.whl.metadata (20 kB)
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (2.2.2)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.10/dist-packages (1.5.2)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.10/dist-packages (3.8.0)
# Requirement already satisfied: torch in /usr/local/lib/python3.10/dist-packages (2.5.1+cu121)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from datasets) (3.16.1)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.10/dist-packages (from datasets) (1.26.4)
# Requirement already satisfied: pyarrow>=15.0.0 in /usr/local/lib/python3.10/dist-packages (from datasets) (17.0.0)
# Collecting dill<0.3.9,>=0.3.0 (from datasets)
#   Downloading dill-0.3.8-py3-none-any.whl.metadata (10 kB)
# Requirement already satisfied: requests>=2.32.2 in /usr/local/lib/python3.10/dist-packages (from datasets) (2.32.3)
# Requirement already satisfied: tqdm>=4.66.3 in /usr/local/lib/python3.10/dist-packages (from datasets) (4.66.6)
# Collecting xxhash (from datasets)
#   Downloading xxhash-3.5.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (12 kB)
# Collecting multiprocess<0.70.17 (from datasets)
#   Downloading multiprocess-0.70.16-py310-none-any.whl.metadata (7.2 kB)
# Collecting fsspec<=2024.9.0,>=2023.1.0 (from fsspec[http]<=2024.9.0,>=2023.1.0->datasets)
#   Downloading fsspec-2024.9.0-py3-none-any.whl.metadata (11 kB)
# Requirement already satisfied: aiohttp in /usr/local/lib/python3.10/dist-packages (from datasets) (3.11.10)
# Requirement already satisfied: huggingface-hub>=0.23.0 in /usr/local/lib/python3.10/dist-packages (from datasets) (0.26.5)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from datasets) (24.2)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from datasets) (6.0.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.10/dist-packages (from pandas) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.10/dist-packages (from pandas) (2024.2)
# Requirement already satisfied: scipy>=1.6.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn) (1.13.1)
# Requirement already satisfied: joblib>=1.2.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn) (1.4.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn) (3.5.0)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (4.55.2)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (1.4.7)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (11.0.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (3.2.0)
# Requirement already satisfied: typing-extensions>=4.8.0 in /usr/local/lib/python3.10/dist-packages (from torch) (4.12.2)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch) (3.4.2)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch) (3.1.4)
# Requirement already satisfied: sympy==1.13.1 in /usr/local/lib/python3.10/dist-packages (from torch) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from sympy==1.13.1->torch) (1.3.0)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (2.4.4)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (1.3.1)
# Requirement already satisfied: async-timeout<6.0,>=4.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (4.0.3)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (24.2.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (1.5.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (6.1.0)
# Requirement already satisfied: propcache>=0.2.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (0.2.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (1.18.3)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests>=2.32.2->datasets) (3.4.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests>=2.32.2->datasets) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests>=2.32.2->datasets) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests>=2.32.2->datasets) (2024.8.30)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch) (3.0.2)
# Downloading datasets-3.2.0-py3-none-any.whl (480 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 480.6/480.6 kB 13.0 MB/s eta 0:00:00
# Downloading dill-0.3.8-py3-none-any.whl (116 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 116.3/116.3 kB 10.4 MB/s eta 0:00:00
# Downloading fsspec-2024.9.0-py3-none-any.whl (179 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 179.3/179.3 kB 17.7 MB/s eta 0:00:00
# Downloading multiprocess-0.70.16-py310-none-any.whl (134 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 134.8/134.8 kB 13.2 MB/s eta 0:00:00
# Downloading xxhash-3.5.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (194 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 194.1/194.1 kB 16.8 MB/s eta 0:00:00
# Installing collected packages: xxhash, fsspec, dill, multiprocess, datasets
#   Attempting uninstall: fsspec
#     Found existing installation: fsspec 2024.10.0
#     Uninstalling fsspec-2024.10.0:
#       Successfully uninstalled fsspec-2024.10.0
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# gcsfs 2024.10.0 requires fsspec==2024.10.0, but you have fsspec 2024.9.0 which is incompatible.
# Successfully installed datasets-3.2.0 dill-0.3.8 fsspec-2024.9.0 multiprocess-0.70.16 xxhash-3.5.0
# Collecting bitsandbytes
#   Downloading bitsandbytes-0.45.0-py3-none-manylinux_2_24_x86_64.whl.metadata (2.9 kB)
# Requirement already satisfied: torch in /usr/local/lib/python3.10/dist-packages (from bitsandbytes) (2.5.1+cu121)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from bitsandbytes) (1.26.4)
# Requirement already satisfied: typing_extensions>=4.8.0 in /usr/local/lib/python3.10/dist-packages (from bitsandbytes) (4.12.2)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from torch->bitsandbytes) (3.16.1)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch->bitsandbytes) (3.4.2)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch->bitsandbytes) (3.1.4)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from torch->bitsandbytes) (2024.9.0)
# Requirement already satisfied: sympy==1.13.1 in /usr/local/lib/python3.10/dist-packages (from torch->bitsandbytes) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from sympy==1.13.1->torch->bitsandbytes) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch->bitsandbytes) (3.0.2)
# Downloading bitsandbytes-0.45.0-py3-none-manylinux_2_24_x86_64.whl (69.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 69.1/69.1 MB 9.7 MB/s eta 0:00:00
# Installing collected packages: bitsandbytes
# Successfully installed bitsandbytes-0.45.0

# %%
# !wget http://www.phontron.com/download/conala-corpus-v1.1.zip -O conala-corpus-v1.1.zip
# !unzip conala-corpus-v1.1.zip -d conala_dataset
# Out:
# --2024-12-12 19:57:22--  http://www.phontron.com/download/conala-corpus-v1.1.zip
# Resolving www.phontron.com (www.phontron.com)... 173.236.247.185
# Connecting to www.phontron.com (www.phontron.com)|173.236.247.185|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 52105440 (50M) [application/zip]
# Saving to: ‘conala-corpus-v1.1.zip’
#
# conala-corpus-v1.1. 100%[===================>]  49.69M  37.5MB/s    in 1.3s
#
# 2024-12-12 19:57:24 (37.5 MB/s) - ‘conala-corpus-v1.1.zip’ saved [52105440/52105440]
#
# Archive:  conala-corpus-v1.1.zip
#    creating: conala_dataset/conala-corpus/
#   inflating: conala_dataset/conala-corpus/conala-mined.jsonl
#   inflating: conala_dataset/conala-corpus/conala-train.json
#   inflating: conala_dataset/conala-corpus/conala-test.json

# %%
import json
import os
# Define the path to the JSON file
json_path = '/content/conala_dataset/conala-corpus/conala-test.json'

# Open and load the JSON file
with open(json_path, 'r', encoding='utf-8') as f:
    data = json.load(f)

# %%
# comment
print(data[0]['rewritten_intent'])
# code
print(data[0]['snippet'])
# Out:
# send a signal `signal.SIGUSR1` to the current process
# os.kill(os.getpid(), signal.SIGUSR1)

# %%
import pandas as pd

df = pd.DataFrame(data)

# %%
df
# Out:
#                                                 intent  \
# 0       How can I send a signal from a python program?
# 1                        Decode Hex String in Python 3
# 2        check if all elements in a list are identical
# 3                            Format string dynamically
# 4       How to convert a string from CP-1251 to UTF-8?
# ..                                                 ...
# 495  Using Regular Expressions to extract specific ...
# 496  Is there a function in Python to split a strin...
# 497                                Open file in Python
# 498           Sum of multiple list of lists index wise
# 499  numpy: syntax/idiom to cast (n,) array to a (n...
#
#                                       rewritten_intent  \
# 0    send a signal `signal.SIGUSR1` to the current ...
# 1               decode a hex string '4a4b4c' to UTF-8.
# 2    check if all elements in list `myList` are ide...
# 3    format number of spaces between strings `Pytho...
# 4                                                 None
# ..                                                 ...
# 495  match urls whose domain doesn't start with `t`...
# 496  split a string `mystring` considering the spac...
# 497                     open file `path` with mode 'r'
# 498      sum elements at the same index in list `data`
# 499                        add a new axis to array `a`
#
#                                                snippet  question_id
# 0                 os.kill(os.getpid(), signal.SIGUSR1)     15080500
# 1              bytes.fromhex('4a4b4c').decode('utf-8')      3283984
# 2                  all(x == myList[0] for x in myList)      3844801
# 3    print('%*s : %*s' % (20, 'Python', 20, 'Very G...      4302166
# 4                    d.decode('cp1251').encode('utf8')      7555335
# ..                                                 ...          ...
# 495   re.findall('http://[^t][^s"]+\\.html', document)     30551576
# 496            mystring.replace(' ', '! !').split('!')       113534
# 497                                    open(path, 'r')      5838735
# 498  [[sum(item) for item in zip(*items)] for items...     36003967
# 499                                 a[:, (np.newaxis)]      7635237
#
# [500 rows x 4 columns]

# %%
df = df[['snippet','rewritten_intent']]

# %%
df = df.dropna()

# %%
# Access the first example
first_example = df.iloc[0]
print("Docstring:\n", first_example['rewritten_intent'])
print()
print("Code:\n", first_example['snippet'])
# Out:
# Docstring:
#  send a signal `signal.SIGUSR1` to the current process
#
# Code:
#  os.kill(os.getpid(), signal.SIGUSR1)

# %%
#remove any non-english comments.
# From https://stackoverflow.com/a/27084708/5768407


def isASCII(s):
    try:
        s.encode(encoding='utf-8').decode('ascii')
    except UnicodeDecodeError:
        return False
    else:
        return True

df = df[df['rewritten_intent'].apply(lambda x: isASCII(x))]

# %%
df = df[~(df['rewritten_intent'] == '')]
df = df[~df['rewritten_intent'].duplicated()]
len(df)
# Out:
# 450

# %%
import pandas as pd
import matplotlib.pyplot as plt
from datasets import load_dataset
from sklearn.model_selection import train_test_split
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity
import numpy as np

# %%
from huggingface_hub import snapshot_download, login

# %%
login(token="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")

# %%
import torch
import re
from transformers import AutoTokenizer, AutoModelForCausalLM

# Load the tokenizer and model
model_name = "meta-llama/Llama-3.2-3B"
tokenizer = AutoTokenizer.from_pretrained(model_name)
model = AutoModelForCausalLM.from_pretrained(
    model_name,
    device_map="auto",
    torch_dtype="auto",
    load_in_8bit=True  # Optional: Use 8-bit precision to save memory
)
# Out:
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# tokenizer_config.json:   0%|          | 0.00/50.5k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/9.09M [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/301 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/844 [00:00<?, ?B/s]
# The `load_in_4bit` and `load_in_8bit` arguments are deprecated and will be removed in the future versions. Please, pass a `BitsAndBytesConfig` object in `quantization_config` argument instead.
# model.safetensors.index.json:   0%|          | 0.00/20.9k [00:00<?, ?B/s]
# Downloading shards:   0%|          | 0/2 [00:00<?, ?it/s]
# model-00001-of-00002.safetensors:   0%|          | 0.00/4.97G [00:00<?, ?B/s]
# model-00002-of-00002.safetensors:   0%|          | 0.00/1.46G [00:00<?, ?B/s]
# Loading checkpoint shards:   0%|          | 0/2 [00:00<?, ?it/s]
# generation_config.json:   0%|          | 0.00/185 [00:00<?, ?B/s]

# %%
model.device
# Out:
# device(type='cuda', index=0)

# %%
def generate_zero_shot_documentation(model, tokenizer, code_snippet, max_length=100):

    prompt = f"Explain the following Python code:\n\n{code_snippet}\n\n Documentation: "

    inputs = tokenizer(prompt, return_tensors="pt").to(model.device)
    outputs = model.generate(
    **inputs,
    max_new_tokens=max_length,
    temperature=0.0,  # Deterministic output
    top_p=0.95,
    do_sample=False,  # Greedy decoding
    eos_token_id=tokenizer.eos_token_id)

    documentation = tokenizer.decode(outputs[0], skip_special_tokens=True)
    doc_start = documentation.find("Documentation:") + len("Documentation:")

    full_doc = documentation[doc_start:].strip()

    # Extract the first two sentences
    doc = full_doc.replace('"""', '').replace('#', '').strip()
    doc =  " ".join(doc.split())
    return doc

# %%
import re
from tqdm import tqdm
import pandas as pd

# %%
generated_comments = []
reference_comments = []

# Iterate over the test set
for _, row in tqdm(df.iterrows(), total=df.shape[0]):
    code = row['snippet']
    reference = row['rewritten_intent']

    generated_comments.append(generate_zero_shot_documentation(model, tokenizer, code, max_length=100))
    reference_comments.append(reference)
# Out:
#   0%|          | 0/450 [00:00<?, ?it/s]/usr/local/lib/python3.10/dist-packages/transformers/generation/configuration_utils.py:590: UserWarning: `do_sample` is set to `False`. However, `temperature` is set to `0.0` -- this flag is only used in sample-based generation modes. You should set `do_sample=True` or unset `temperature`.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/transformers/generation/configuration_utils.py:595: UserWarning: `do_sample` is set to `False`. However, `top_p` is set to `0.95` -- this flag is only used in sample-based generation modes. You should set `do_sample=True` or unset `top_p`.
#   warnings.warn(
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# /usr/local/lib/python3.10/dist-packages/bitsandbytes/autograd/_functions.py:315: UserWarning: MatMul8bitLt: inputs will be cast from torch.bfloat16 to float16 during quantization
#   warnings.warn(f"MatMul8bitLt: inputs will be cast from {A.dtype} to float16 during quantization")
#   0%|          | 1/450 [00:12<1:37:13, 12.99s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#   0%|          | 2/450 [00:24<1:29:23, 11.97s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#   1%|          | 3/450 [00:35<1:27:50, 11.79s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#   1%|          | 4/450 [00:47<1:26:39, 11.66s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#   1%|          | 5/450 [00:58<1:26:18, 11.64s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#   1%|▏         | 6/450 [01:10<1:26:01, 11.62s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#   2%|▏         | 7/450 [01:22<1:25:40, 11.60s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#   2%|▏         | 8/450 [01:33<1:25:24, 11.59s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#   2%|▏         | 9/450 [01:45<1:25:05, 11.58s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#   2%|▏         | 10/450 [01:56<1:24:33, 11.53s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#   2%|▏         | 11/450 [02:07<1:23:52, 11.46s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#   3%|▎         | 12/450 [02:19<1:23:42, 11.47s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#   3%|▎         | 13/450 [02:30<1:23:32, 11.47s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#   3%|▎         | 14/450 [02:42<1:23:42, 11.52s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#   3%|▎         | 15/450 [02:53<1:23:19, 11.49s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#   4%|▎         | 16/450 [03:05<1:23:21, 11.52s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#   4%|▍         | 17/450 [03:17<1:23:32, 11.58s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#   4%|▍         | 18/450 [03:28<1:23:38, 11.62s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#   4%|▍         | 19/450 [03:40<1:23:12, 11.58s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#   4%|▍         | 20/450 [03:52<1:23:00, 11.58s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#   5%|▍         | 21/450 [04:04<1:24:20, 11.80s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#   5%|▍         | 22/450 [04:15<1:23:10, 11.66s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#   5%|▌         | 23/450 [04:27<1:22:38, 11.61s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#   5%|▌         | 24/450 [04:38<1:22:36, 11.64s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#   6%|▌         | 25/450 [04:50<1:22:49, 11.69s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#   6%|▌         | 26/450 [05:02<1:22:17, 11.65s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#   6%|▌         | 27/450 [05:13<1:22:05, 11.64s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#   6%|▌         | 28/450 [05:25<1:21:26, 11.58s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#   6%|▋         | 29/450 [05:36<1:21:04, 11.55s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#   7%|▋         | 30/450 [05:48<1:21:02, 11.58s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#   7%|▋         | 31/450 [05:59<1:20:44, 11.56s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#   7%|▋         | 32/450 [06:11<1:19:57, 11.48s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#   7%|▋         | 33/450 [06:22<1:19:30, 11.44s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#   8%|▊         | 34/450 [06:34<1:19:35, 11.48s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#   8%|▊         | 35/450 [06:45<1:19:29, 11.49s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#   8%|▊         | 36/450 [06:57<1:19:41, 11.55s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#   8%|▊         | 37/450 [07:09<1:21:14, 11.80s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#   8%|▊         | 38/450 [07:21<1:20:26, 11.71s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#   9%|▊         | 39/450 [07:32<1:20:03, 11.69s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#   9%|▉         | 40/450 [07:44<1:19:02, 11.57s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#   9%|▉         | 41/450 [07:55<1:19:23, 11.65s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#   9%|▉         | 42/450 [08:07<1:18:55, 11.61s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  10%|▉         | 43/450 [08:19<1:19:40, 11.75s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  10%|▉         | 44/450 [08:30<1:18:23, 11.59s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  10%|█         | 45/450 [08:42<1:17:40, 11.51s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  10%|█         | 46/450 [08:53<1:17:41, 11.54s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  10%|█         | 47/450 [09:05<1:17:38, 11.56s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  11%|█         | 48/450 [09:16<1:17:20, 11.54s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  11%|█         | 49/450 [09:28<1:17:04, 11.53s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  11%|█         | 50/450 [09:39<1:16:35, 11.49s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  11%|█▏        | 51/450 [09:51<1:17:00, 11.58s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  12%|█▏        | 52/450 [10:02<1:16:37, 11.55s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  12%|█▏        | 53/450 [10:14<1:16:22, 11.54s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  12%|█▏        | 54/450 [10:25<1:15:20, 11.41s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  12%|█▏        | 55/450 [10:37<1:15:23, 11.45s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  12%|█▏        | 56/450 [10:48<1:15:35, 11.51s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  13%|█▎        | 57/450 [11:00<1:15:25, 11.52s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  13%|█▎        | 58/450 [11:11<1:15:16, 11.52s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  13%|█▎        | 59/450 [11:23<1:15:31, 11.59s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  13%|█▎        | 60/450 [11:35<1:15:11, 11.57s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  14%|█▎        | 61/450 [11:46<1:14:56, 11.56s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  14%|█▍        | 62/450 [11:58<1:16:08, 11.78s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  14%|█▍        | 63/450 [12:10<1:16:06, 11.80s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  14%|█▍        | 64/450 [12:14<59:47,  9.29s/it]  Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  14%|█▍        | 65/450 [12:27<1:07:10, 10.47s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  15%|█▍        | 66/450 [12:39<1:09:44, 10.90s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  15%|█▍        | 67/450 [12:51<1:12:25, 11.34s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  15%|█▌        | 68/450 [13:03<1:13:36, 11.56s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  15%|█▌        | 69/450 [13:15<1:14:19, 11.70s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  16%|█▌        | 70/450 [13:27<1:13:44, 11.64s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  16%|█▌        | 71/450 [13:38<1:13:21, 11.61s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  16%|█▌        | 72/450 [13:50<1:13:47, 11.71s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  16%|█▌        | 73/450 [14:02<1:13:37, 11.72s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  16%|█▋        | 74/450 [14:14<1:13:47, 11.78s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  17%|█▋        | 75/450 [14:26<1:14:01, 11.84s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  17%|█▋        | 76/450 [14:38<1:13:47, 11.84s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  17%|█▋        | 77/450 [14:50<1:13:39, 11.85s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  17%|█▋        | 78/450 [15:02<1:13:23, 11.84s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  18%|█▊        | 79/450 [15:13<1:13:21, 11.86s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  18%|█▊        | 80/450 [15:25<1:13:11, 11.87s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  18%|█▊        | 81/450 [15:37<1:13:15, 11.91s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  18%|█▊        | 82/450 [15:49<1:12:19, 11.79s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  18%|█▊        | 83/450 [16:00<1:11:09, 11.63s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  19%|█▊        | 84/450 [16:12<1:11:04, 11.65s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  19%|█▉        | 85/450 [16:24<1:11:02, 11.68s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  19%|█▉        | 86/450 [16:36<1:12:08, 11.89s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  19%|█▉        | 87/450 [16:48<1:11:45, 11.86s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  20%|█▉        | 88/450 [16:59<1:11:12, 11.80s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  20%|█▉        | 89/450 [17:11<1:10:51, 11.78s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  20%|██        | 90/450 [17:23<1:10:14, 11.71s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  20%|██        | 91/450 [17:35<1:10:23, 11.76s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  20%|██        | 92/450 [17:46<1:09:58, 11.73s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  21%|██        | 93/450 [17:58<1:09:46, 11.73s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  21%|██        | 94/450 [18:09<1:08:38, 11.57s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  21%|██        | 95/450 [18:21<1:08:23, 11.56s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  21%|██▏       | 96/450 [18:32<1:08:27, 11.60s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  22%|██▏       | 97/450 [18:44<1:08:34, 11.65s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  22%|██▏       | 98/450 [18:56<1:07:56, 11.58s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  22%|██▏       | 99/450 [19:07<1:08:02, 11.63s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  22%|██▏       | 100/450 [19:19<1:07:52, 11.64s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  22%|██▏       | 101/450 [19:31<1:07:46, 11.65s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  23%|██▎       | 102/450 [19:42<1:07:27, 11.63s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  23%|██▎       | 103/450 [19:54<1:07:07, 11.61s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  23%|██▎       | 104/450 [19:55<49:45,  8.63s/it]  Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  23%|██▎       | 105/450 [20:07<54:41,  9.51s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  24%|██▎       | 106/450 [20:19<58:00, 10.12s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  24%|██▍       | 107/450 [20:30<59:38, 10.43s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  24%|██▍       | 108/450 [20:42<1:02:12, 10.91s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  24%|██▍       | 109/450 [20:53<1:02:51, 11.06s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  24%|██▍       | 110/450 [21:05<1:03:35, 11.22s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  25%|██▍       | 111/450 [21:16<1:03:56, 11.32s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  25%|██▍       | 112/450 [21:28<1:04:29, 11.45s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  25%|██▌       | 113/450 [21:40<1:04:45, 11.53s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  25%|██▌       | 114/450 [21:52<1:05:48, 11.75s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  26%|██▌       | 115/450 [22:04<1:05:30, 11.73s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  26%|██▌       | 116/450 [22:15<1:05:10, 11.71s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  26%|██▌       | 117/450 [22:27<1:04:57, 11.70s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  26%|██▌       | 118/450 [22:39<1:04:34, 11.67s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  26%|██▋       | 119/450 [22:50<1:03:21, 11.48s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  27%|██▋       | 120/450 [23:01<1:03:01, 11.46s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  27%|██▋       | 121/450 [23:13<1:03:25, 11.57s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  27%|██▋       | 122/450 [23:24<1:03:05, 11.54s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  27%|██▋       | 123/450 [23:36<1:03:07, 11.58s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  28%|██▊       | 124/450 [23:48<1:02:56, 11.58s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  28%|██▊       | 125/450 [23:59<1:02:50, 11.60s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  28%|██▊       | 126/450 [24:11<1:02:26, 11.56s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  28%|██▊       | 127/450 [24:22<1:02:21, 11.58s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  28%|██▊       | 128/450 [24:34<1:02:17, 11.61s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  29%|██▊       | 129/450 [24:46<1:03:24, 11.85s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  29%|██▉       | 130/450 [24:58<1:02:47, 11.77s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  29%|██▉       | 131/450 [25:09<1:01:45, 11.62s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  29%|██▉       | 132/450 [25:21<1:01:26, 11.59s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  30%|██▉       | 133/450 [25:33<1:01:40, 11.67s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  30%|██▉       | 134/450 [25:45<1:01:56, 11.76s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  30%|███       | 135/450 [25:56<1:01:30, 11.72s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  30%|███       | 136/450 [26:08<1:01:06, 11.68s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  30%|███       | 137/450 [26:20<1:00:59, 11.69s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  31%|███       | 138/450 [26:31<1:00:46, 11.69s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  31%|███       | 139/450 [26:43<1:00:30, 11.67s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  31%|███       | 140/450 [26:55<1:00:13, 11.66s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  31%|███▏      | 141/450 [27:06<59:31, 11.56s/it]  Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  32%|███▏      | 142/450 [27:17<59:13, 11.54s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  32%|███▏      | 143/450 [27:29<59:14, 11.58s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  32%|███▏      | 144/450 [27:41<59:17, 11.63s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  32%|███▏      | 145/450 [27:52<58:50, 11.58s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  32%|███▏      | 146/450 [28:04<59:00, 11.65s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  33%|███▎      | 147/450 [28:16<58:35, 11.60s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  33%|███▎      | 148/450 [28:27<58:16, 11.58s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  33%|███▎      | 149/450 [28:39<58:17, 11.62s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  33%|███▎      | 150/450 [28:51<59:12, 11.84s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  34%|███▎      | 151/450 [29:03<58:35, 11.76s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  34%|███▍      | 152/450 [29:14<57:48, 11.64s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  34%|███▍      | 153/450 [29:20<49:51, 10.07s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  34%|███▍      | 154/450 [29:32<51:57, 10.53s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  34%|███▍      | 155/450 [29:44<53:09, 10.81s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  35%|███▍      | 156/450 [29:55<54:01, 11.03s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  35%|███▍      | 157/450 [30:07<54:33, 11.17s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  35%|███▌      | 158/450 [30:18<54:59, 11.30s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  35%|███▌      | 159/450 [30:30<54:50, 11.31s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  36%|███▌      | 160/450 [30:41<54:17, 11.23s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  36%|███▌      | 161/450 [30:52<54:24, 11.30s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  36%|███▌      | 162/450 [31:04<54:39, 11.39s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  36%|███▌      | 163/450 [31:15<54:33, 11.41s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  36%|███▋      | 164/450 [31:26<54:20, 11.40s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  37%|███▋      | 165/450 [31:38<54:32, 11.48s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  37%|███▋      | 166/450 [31:50<54:35, 11.53s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  37%|███▋      | 167/450 [32:01<54:23, 11.53s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  37%|███▋      | 168/450 [32:13<54:17, 11.55s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  38%|███▊      | 169/450 [32:24<53:59, 11.53s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  38%|███▊      | 170/450 [32:33<50:16, 10.77s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  38%|███▊      | 172/450 [32:57<52:24, 11.31s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  38%|███▊      | 173/450 [33:09<52:22, 11.34s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  39%|███▊      | 174/450 [33:20<52:23, 11.39s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  39%|███▉      | 175/450 [33:32<52:27, 11.45s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  39%|███▉      | 176/450 [33:43<52:25, 11.48s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  39%|███▉      | 177/450 [33:55<52:23, 11.51s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  40%|███▉      | 178/450 [34:06<52:12, 11.52s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  40%|███▉      | 179/450 [34:17<51:14, 11.35s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  40%|████      | 180/450 [34:29<51:17, 11.40s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  40%|████      | 181/450 [34:40<51:11, 11.42s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  40%|████      | 182/450 [34:52<50:59, 11.42s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  41%|████      | 183/450 [35:03<51:04, 11.48s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  41%|████      | 184/450 [35:15<50:52, 11.48s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  41%|████      | 185/450 [35:26<50:33, 11.45s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  41%|████▏     | 186/450 [35:38<50:26, 11.46s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  42%|████▏     | 187/450 [35:49<50:35, 11.54s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  42%|████▏     | 188/450 [36:01<50:31, 11.57s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  42%|████▏     | 189/450 [36:12<49:50, 11.46s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  42%|████▏     | 190/450 [36:23<49:16, 11.37s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  42%|████▏     | 191/450 [36:35<49:24, 11.45s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  43%|████▎     | 192/450 [36:48<51:26, 11.96s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  43%|████▎     | 193/450 [37:01<52:34, 12.27s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  43%|████▎     | 194/450 [37:14<52:34, 12.32s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  43%|████▎     | 195/450 [37:26<52:12, 12.29s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  44%|████▎     | 196/450 [37:38<52:10, 12.32s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  44%|████▍     | 197/450 [37:50<51:45, 12.28s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  44%|████▍     | 198/450 [38:03<51:31, 12.27s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  44%|████▍     | 199/450 [38:15<51:05, 12.21s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  44%|████▍     | 200/450 [38:26<50:03, 12.01s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  45%|████▍     | 201/450 [38:38<49:28, 11.92s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  45%|████▍     | 202/450 [38:50<48:55, 11.84s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  45%|████▌     | 203/450 [39:01<48:35, 11.80s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  45%|████▌     | 204/450 [39:13<47:55, 11.69s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  46%|████▌     | 205/450 [39:24<47:29, 11.63s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  46%|████▌     | 206/450 [39:37<48:02, 11.81s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  46%|████▌     | 207/450 [39:48<47:40, 11.77s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  46%|████▌     | 208/450 [40:00<47:37, 11.81s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  46%|████▋     | 209/450 [40:12<47:36, 11.85s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  47%|████▋     | 210/450 [40:24<47:28, 11.87s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  47%|████▋     | 211/450 [40:36<47:12, 11.85s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  47%|████▋     | 212/450 [40:48<47:56, 12.09s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  47%|████▋     | 213/450 [41:00<47:28, 12.02s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  48%|████▊     | 214/450 [41:12<46:50, 11.91s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  48%|████▊     | 215/450 [41:24<46:45, 11.94s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  48%|████▊     | 216/450 [41:36<46:28, 11.92s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  48%|████▊     | 217/450 [41:47<45:37, 11.75s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  48%|████▊     | 218/450 [41:59<44:58, 11.63s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  49%|████▊     | 219/450 [42:10<44:55, 11.67s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  49%|████▉     | 220/450 [42:22<44:34, 11.63s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  49%|████▉     | 221/450 [42:34<44:44, 11.72s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  49%|████▉     | 222/450 [42:45<44:32, 11.72s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  50%|████▉     | 223/450 [42:57<44:29, 11.76s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  50%|████▉     | 224/450 [43:09<44:05, 11.71s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  50%|█████     | 225/450 [43:21<43:55, 11.71s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  50%|█████     | 226/450 [43:33<44:11, 11.84s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  50%|█████     | 227/450 [43:45<44:17, 11.92s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  51%|█████     | 228/450 [43:56<43:42, 11.81s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  51%|█████     | 229/450 [44:08<42:48, 11.62s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  51%|█████     | 230/450 [44:19<42:19, 11.54s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  51%|█████▏    | 231/450 [44:31<42:17, 11.59s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  52%|█████▏    | 232/450 [44:43<42:58, 11.83s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  52%|█████▏    | 233/450 [44:55<42:37, 11.79s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  52%|█████▏    | 234/450 [45:06<42:13, 11.73s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  52%|█████▏    | 235/450 [45:18<42:00, 11.73s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  52%|█████▏    | 236/450 [45:30<41:49, 11.72s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  53%|█████▎    | 237/450 [45:41<41:31, 11.70s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  53%|█████▎    | 238/450 [45:53<41:17, 11.69s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  53%|█████▎    | 239/450 [46:04<40:45, 11.59s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  53%|█████▎    | 240/450 [46:16<40:09, 11.47s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  54%|█████▎    | 241/450 [46:27<40:15, 11.56s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  54%|█████▍    | 242/450 [46:40<40:39, 11.73s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  54%|█████▍    | 243/450 [46:51<40:26, 11.72s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  54%|█████▍    | 244/450 [47:03<40:07, 11.69s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  54%|█████▍    | 245/450 [47:15<39:55, 11.68s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  55%|█████▍    | 246/450 [47:26<39:52, 11.73s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  55%|█████▍    | 247/450 [47:38<39:44, 11.74s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  55%|█████▌    | 248/450 [47:50<39:32, 11.75s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  55%|█████▌    | 249/450 [48:01<39:11, 11.70s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  56%|█████▌    | 250/450 [48:13<38:44, 11.62s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  56%|█████▌    | 251/450 [48:24<38:17, 11.55s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  56%|█████▌    | 252/450 [48:37<38:51, 11.77s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  56%|█████▌    | 253/450 [48:48<38:34, 11.75s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  56%|█████▋    | 254/450 [49:00<38:16, 11.72s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  57%|█████▋    | 255/450 [49:11<37:51, 11.65s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  57%|█████▋    | 256/450 [49:23<37:31, 11.61s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  57%|█████▋    | 257/450 [49:34<37:13, 11.57s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  57%|█████▋    | 258/450 [49:46<37:00, 11.57s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  58%|█████▊    | 259/450 [49:57<36:33, 11.49s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  58%|█████▊    | 260/450 [50:09<36:16, 11.46s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  58%|█████▊    | 261/450 [50:20<35:52, 11.39s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  58%|█████▊    | 262/450 [50:31<35:49, 11.43s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  58%|█████▊    | 263/450 [50:43<35:48, 11.49s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  59%|█████▊    | 264/450 [50:55<35:41, 11.51s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  59%|█████▉    | 265/450 [51:06<35:47, 11.61s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  59%|█████▉    | 266/450 [51:18<35:57, 11.73s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  59%|█████▉    | 267/450 [51:30<35:47, 11.73s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  60%|█████▉    | 268/450 [51:42<35:33, 11.72s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  60%|█████▉    | 269/450 [51:54<35:55, 11.91s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  60%|██████    | 270/450 [52:06<35:38, 11.88s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  60%|██████    | 271/450 [52:16<33:59, 11.39s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  60%|██████    | 272/450 [52:28<33:46, 11.38s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  61%|██████    | 273/450 [52:40<34:33, 11.72s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  61%|██████    | 274/450 [52:52<34:08, 11.64s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  61%|██████    | 275/450 [53:03<33:52, 11.61s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  61%|██████▏   | 276/450 [53:15<33:32, 11.57s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  62%|██████▏   | 277/450 [53:26<33:14, 11.53s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  62%|██████▏   | 278/450 [53:37<32:51, 11.46s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  62%|██████▏   | 279/450 [53:49<32:25, 11.38s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  62%|██████▏   | 280/450 [54:00<32:04, 11.32s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  62%|██████▏   | 281/450 [54:11<32:03, 11.38s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  63%|██████▎   | 282/450 [54:23<32:02, 11.44s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  63%|██████▎   | 283/450 [54:34<31:46, 11.42s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  63%|██████▎   | 284/450 [54:46<31:39, 11.44s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  63%|██████▎   | 285/450 [54:57<31:22, 11.41s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  64%|██████▎   | 286/450 [55:09<31:14, 11.43s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  64%|██████▍   | 287/450 [55:20<30:58, 11.40s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  64%|██████▍   | 288/450 [55:31<30:40, 11.36s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  64%|██████▍   | 289/450 [55:42<30:12, 11.26s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  64%|██████▍   | 290/450 [55:54<30:15, 11.35s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  65%|██████▍   | 291/450 [56:05<30:03, 11.34s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  65%|██████▍   | 292/450 [56:17<29:58, 11.38s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  65%|██████▌   | 293/450 [56:29<30:30, 11.66s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  65%|██████▌   | 294/450 [56:40<30:15, 11.64s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  66%|██████▌   | 295/450 [56:52<30:03, 11.63s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  66%|██████▌   | 296/450 [57:04<29:49, 11.62s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  66%|██████▌   | 297/450 [57:15<29:36, 11.61s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  66%|██████▌   | 298/450 [57:26<29:05, 11.48s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  66%|██████▋   | 299/450 [57:37<28:29, 11.32s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  67%|██████▋   | 300/450 [57:49<28:11, 11.28s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  67%|██████▋   | 301/450 [58:00<28:04, 11.30s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  67%|██████▋   | 302/450 [58:11<27:55, 11.32s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  67%|██████▋   | 303/450 [58:23<27:49, 11.36s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  68%|██████▊   | 304/450 [58:34<27:40, 11.38s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  68%|██████▊   | 305/450 [58:46<27:33, 11.40s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  68%|██████▊   | 307/450 [59:09<27:21, 11.48s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  68%|██████▊   | 308/450 [59:20<27:20, 11.56s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  69%|██████▊   | 309/450 [59:31<26:43, 11.38s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  69%|██████▉   | 310/450 [59:43<26:34, 11.39s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  69%|██████▉   | 311/450 [59:43<18:34,  8.02s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  69%|██████▉   | 312/450 [59:54<20:50,  9.06s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  70%|██████▉   | 313/450 [1:00:06<22:21,  9.79s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  70%|██████▉   | 314/450 [1:00:18<24:01, 10.60s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  70%|███████   | 315/450 [1:00:30<24:28, 10.88s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  70%|███████   | 316/450 [1:00:42<24:43, 11.07s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  70%|███████   | 317/450 [1:00:53<24:52, 11.22s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  71%|███████   | 318/450 [1:01:05<24:50, 11.29s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  71%|███████   | 319/450 [1:01:16<24:44, 11.33s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  71%|███████   | 320/450 [1:01:27<24:24, 11.26s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  71%|███████▏  | 321/450 [1:01:38<24:12, 11.26s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  72%|███████▏  | 322/450 [1:01:50<24:13, 11.36s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  72%|███████▏  | 323/450 [1:02:01<24:07, 11.40s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  72%|███████▏  | 324/450 [1:02:06<19:30,  9.29s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  72%|███████▏  | 325/450 [1:02:17<20:31,  9.85s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  72%|███████▏  | 326/450 [1:02:28<21:21, 10.34s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  73%|███████▎  | 327/450 [1:02:40<21:59, 10.72s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  73%|███████▎  | 328/450 [1:02:52<22:30, 11.07s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  73%|███████▎  | 329/450 [1:03:04<22:48, 11.31s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  73%|███████▎  | 330/450 [1:03:16<22:52, 11.44s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  74%|███████▎  | 331/450 [1:03:27<22:46, 11.49s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  74%|███████▍  | 332/450 [1:03:39<22:41, 11.54s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  74%|███████▍  | 333/450 [1:03:51<22:41, 11.63s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  74%|███████▍  | 334/450 [1:04:03<22:39, 11.72s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  74%|███████▍  | 335/450 [1:04:15<22:58, 11.98s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  75%|███████▍  | 336/450 [1:04:27<22:28, 11.83s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  75%|███████▍  | 337/450 [1:04:38<22:09, 11.77s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  75%|███████▌  | 338/450 [1:04:50<21:57, 11.76s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  75%|███████▌  | 339/450 [1:05:03<22:10, 11.99s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  76%|███████▌  | 340/450 [1:05:14<21:53, 11.94s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  76%|███████▌  | 341/450 [1:05:26<21:34, 11.88s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  76%|███████▌  | 342/450 [1:05:38<21:14, 11.80s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  76%|███████▌  | 343/450 [1:05:49<21:00, 11.78s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  76%|███████▋  | 344/450 [1:06:01<20:39, 11.69s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  77%|███████▋  | 345/450 [1:06:12<20:21, 11.63s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  77%|███████▋  | 346/450 [1:06:24<20:07, 11.61s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  77%|███████▋  | 347/450 [1:06:35<19:49, 11.55s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  77%|███████▋  | 348/450 [1:06:47<19:28, 11.45s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  78%|███████▊  | 349/450 [1:06:58<19:10, 11.39s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  78%|███████▊  | 350/450 [1:07:10<19:12, 11.52s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  78%|███████▊  | 351/450 [1:07:21<19:05, 11.57s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  78%|███████▊  | 352/450 [1:07:33<18:55, 11.58s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  78%|███████▊  | 353/450 [1:07:44<18:41, 11.56s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  79%|███████▊  | 354/450 [1:07:57<18:55, 11.83s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  79%|███████▉  | 355/450 [1:08:08<18:31, 11.69s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  79%|███████▉  | 356/450 [1:08:20<18:20, 11.71s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  79%|███████▉  | 357/450 [1:08:32<18:03, 11.65s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  80%|███████▉  | 358/450 [1:08:42<17:31, 11.43s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  80%|███████▉  | 359/450 [1:08:54<17:16, 11.39s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  80%|████████  | 360/450 [1:09:05<17:10, 11.45s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  80%|████████  | 361/450 [1:09:17<17:01, 11.48s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  80%|████████  | 362/450 [1:09:28<16:51, 11.49s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  81%|████████  | 363/450 [1:09:40<16:40, 11.50s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  81%|████████  | 364/450 [1:09:52<16:37, 11.59s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  81%|████████  | 365/450 [1:10:03<16:26, 11.61s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  81%|████████▏ | 366/450 [1:10:15<16:09, 11.54s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  82%|████████▏ | 367/450 [1:10:26<15:48, 11.43s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  82%|████████▏ | 368/450 [1:10:37<15:33, 11.38s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  82%|████████▏ | 369/450 [1:10:49<15:30, 11.49s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  82%|████████▏ | 370/450 [1:11:01<15:23, 11.55s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  82%|████████▏ | 371/450 [1:11:12<15:14, 11.57s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  83%|████████▎ | 372/450 [1:11:24<15:05, 11.62s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  83%|████████▎ | 373/450 [1:11:36<15:11, 11.84s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  83%|████████▎ | 374/450 [1:11:48<15:01, 11.86s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  83%|████████▎ | 375/450 [1:12:00<14:45, 11.80s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  84%|████████▎ | 376/450 [1:12:12<14:28, 11.74s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  84%|████████▍ | 377/450 [1:12:23<14:12, 11.68s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  84%|████████▍ | 378/450 [1:12:34<13:53, 11.58s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  84%|████████▍ | 379/450 [1:12:46<13:39, 11.55s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  84%|████████▍ | 380/450 [1:12:58<13:31, 11.59s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  85%|████████▍ | 381/450 [1:13:09<13:18, 11.58s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  85%|████████▍ | 382/450 [1:13:21<13:07, 11.58s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  85%|████████▌ | 383/450 [1:13:33<13:05, 11.72s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  85%|████████▌ | 384/450 [1:13:45<13:02, 11.85s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  86%|████████▌ | 385/450 [1:13:57<12:50, 11.85s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  86%|████████▌ | 386/450 [1:14:08<12:35, 11.81s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  86%|████████▌ | 387/450 [1:14:20<12:20, 11.75s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  86%|████████▌ | 388/450 [1:14:31<11:51, 11.48s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  86%|████████▋ | 389/450 [1:14:42<11:37, 11.43s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  87%|████████▋ | 390/450 [1:14:54<11:28, 11.47s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  87%|████████▋ | 391/450 [1:15:05<11:16, 11.46s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  87%|████████▋ | 392/450 [1:15:17<11:06, 11.50s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  87%|████████▋ | 393/450 [1:15:29<11:08, 11.73s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  88%|████████▊ | 394/450 [1:15:41<10:56, 11.72s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  88%|████████▊ | 395/450 [1:15:52<10:42, 11.69s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  88%|████████▊ | 396/450 [1:16:04<10:28, 11.64s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  88%|████████▊ | 397/450 [1:16:15<10:13, 11.57s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  88%|████████▊ | 398/450 [1:16:27<09:57, 11.49s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  89%|████████▊ | 399/450 [1:16:38<09:40, 11.38s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  89%|████████▉ | 400/450 [1:16:49<09:28, 11.38s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  89%|████████▉ | 401/450 [1:16:59<08:55, 10.93s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  89%|████████▉ | 402/450 [1:17:07<08:00, 10.01s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  90%|████████▉ | 403/450 [1:17:19<08:13, 10.50s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  90%|████████▉ | 404/450 [1:17:30<08:11, 10.68s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  90%|█████████ | 405/450 [1:17:41<08:09, 10.87s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  90%|█████████ | 406/450 [1:17:53<08:09, 11.12s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  90%|█████████ | 407/450 [1:18:04<08:02, 11.22s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  91%|█████████ | 408/450 [1:18:16<07:53, 11.28s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  91%|█████████ | 409/450 [1:18:27<07:46, 11.37s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  91%|█████████ | 410/450 [1:18:39<07:36, 11.41s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  91%|█████████▏| 411/450 [1:18:50<07:25, 11.43s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  92%|█████████▏| 412/450 [1:19:02<07:16, 11.48s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  92%|█████████▏| 413/450 [1:19:13<07:05, 11.51s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  92%|█████████▏| 414/450 [1:19:25<06:56, 11.56s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  92%|█████████▏| 415/450 [1:19:36<06:43, 11.53s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  92%|█████████▏| 416/450 [1:19:48<06:33, 11.57s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  93%|█████████▎| 417/450 [1:19:58<06:08, 11.17s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  93%|█████████▎| 418/450 [1:20:10<06:00, 11.27s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  93%|█████████▎| 419/450 [1:20:21<05:51, 11.35s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  93%|█████████▎| 420/450 [1:20:33<05:39, 11.31s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  94%|█████████▎| 421/450 [1:20:44<05:26, 11.25s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  94%|█████████▍| 422/450 [1:20:55<05:18, 11.36s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  94%|█████████▍| 423/450 [1:21:07<05:08, 11.43s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  94%|█████████▍| 424/450 [1:21:18<04:58, 11.46s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  94%|█████████▍| 425/450 [1:21:30<04:45, 11.44s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  95%|█████████▍| 426/450 [1:21:41<04:35, 11.48s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  95%|█████████▍| 427/450 [1:21:53<04:24, 11.51s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  95%|█████████▌| 428/450 [1:22:04<04:12, 11.49s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  95%|█████████▌| 429/450 [1:22:16<04:00, 11.46s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  96%|█████████▌| 430/450 [1:22:27<03:47, 11.35s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  96%|█████████▌| 431/450 [1:22:38<03:35, 11.35s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  96%|█████████▌| 432/450 [1:22:51<03:32, 11.81s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  96%|█████████▌| 433/450 [1:23:03<03:18, 11.69s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  96%|█████████▋| 434/450 [1:23:14<03:06, 11.64s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  97%|█████████▋| 435/450 [1:23:26<02:54, 11.63s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  97%|█████████▋| 436/450 [1:23:37<02:42, 11.60s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  97%|█████████▋| 437/450 [1:23:49<02:31, 11.62s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  97%|█████████▋| 438/450 [1:24:00<02:19, 11.60s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  98%|█████████▊| 439/450 [1:24:12<02:06, 11.49s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  98%|█████████▊| 440/450 [1:24:23<01:54, 11.45s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  98%|█████████▊| 441/450 [1:24:34<01:42, 11.41s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  98%|█████████▊| 442/450 [1:24:46<01:31, 11.43s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  98%|█████████▊| 443/450 [1:24:57<01:20, 11.43s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  99%|█████████▊| 444/450 [1:25:09<01:08, 11.44s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  99%|█████████▉| 445/450 [1:25:20<00:57, 11.47s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  99%|█████████▉| 446/450 [1:25:32<00:45, 11.50s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  99%|█████████▉| 447/450 [1:25:43<00:34, 11.49s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# 100%|█████████▉| 448/450 [1:25:55<00:23, 11.51s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# 100%|█████████▉| 449/450 [1:26:06<00:11, 11.33s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# 100%|██████████| 450/450 [1:26:17<00:00, 11.51s/it]

# %%
# !pip install rouge-score
# Out:
# Collecting rouge-score
#   Downloading rouge_score-0.1.2.tar.gz (17 kB)
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: absl-py in /usr/local/lib/python3.10/dist-packages (from rouge-score) (1.4.0)
# Requirement already satisfied: nltk in /usr/local/lib/python3.10/dist-packages (from rouge-score) (3.9.1)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from rouge-score) (1.26.4)
# Requirement already satisfied: six>=1.14.0 in /usr/local/lib/python3.10/dist-packages (from rouge-score) (1.17.0)
# Requirement already satisfied: click in /usr/local/lib/python3.10/dist-packages (from nltk->rouge-score) (8.1.7)
# Requirement already satisfied: joblib in /usr/local/lib/python3.10/dist-packages (from nltk->rouge-score) (1.4.2)
# Requirement already satisfied: regex>=2021.8.3 in /usr/local/lib/python3.10/dist-packages (from nltk->rouge-score) (2024.9.11)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from nltk->rouge-score) (4.66.6)
# Building wheels for collected packages: rouge-score
#   Building wheel for rouge-score (setup.py) ... done
#   Created wheel for rouge-score: filename=rouge_score-0.1.2-py3-none-any.whl size=24935 sha256=14f668a10b55b9dffb89cddf9b91442e410e586a88e87e3dfeb0d33496cb344f
#   Stored in directory: /root/.cache/pip/wheels/5f/dd/89/461065a73be61a532ff8599a28e9beef17985c9e9c31e541b4
# Successfully built rouge-score
# Installing collected packages: rouge-score
# Successfully installed rouge-score-0.1.2

# %%
from nltk.translate.bleu_score import corpus_bleu
from rouge_score import rouge_scorer
from nltk.translate.meteor_score import meteor_score
import nltk
nltk.download('punkt')
nltk.download('punkt_tab')
nltk.download('wordnet')
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# [nltk_data] Downloading package punkt_tab to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt_tab.zip.
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# True

# %%
def evaluate_generated_comments(reference_comments, generated_comments):

    # Tokenize for BLEU
    tokenized_generated = [nltk.word_tokenize(comment.lower()) for comment in generated_comments]
    tokenized_reference = [[nltk.word_tokenize(ref.lower())] for ref in reference_comments]

    # BLEU-2
    bleu_score = corpus_bleu(tokenized_reference, tokenized_generated, weights=(0.5, 0.5))  # BLEU-2

    # ROUGE
    scorer = rouge_scorer.RougeScorer(['rouge1', 'rouge2', 'rougeL'], use_stemmer=True)
    rouge1, rouge2, rougeL = 0, 0, 0
    for ref, gen in zip(reference_comments, generated_comments):
        scores = scorer.score(ref, gen)
        rouge1 += scores['rouge1'].fmeasure
        rouge2 += scores['rouge2'].fmeasure
        rougeL += scores['rougeL'].fmeasure
    rouge1 /= len(reference_comments)
    rouge2 /= len(reference_comments)
    rougeL /= len(reference_comments)

    # METEOR
    meteor = 0
    for ref, gen in zip(reference_comments, generated_comments):
        # Tokenize the hypothesis and references
        ref_tokens = nltk.word_tokenize(ref.lower())
        gen_tokens = nltk.word_tokenize(gen.lower())

        # Compute METEOR for each pair
        meteor += meteor_score([ref_tokens], gen_tokens)
    meteor /= len(reference_comments)

    return {
        'BLEU-2': bleu_score,
        'ROUGE-1': rouge1,
        'ROUGE-2': rouge2,
        'ROUGE-L': rougeL,
        'METEOR': meteor
    }

# %%
metrics = evaluate_generated_comments(reference_comments, generated_comments)
for metric, score in metrics.items():
    print(f"{metric}: {score:.4f}")
# Out:
# BLEU-2: 0.0203
# ROUGE-1: 0.0827
# ROUGE-2: 0.0186
# ROUGE-L: 0.0743
# METEOR: 0.0881

# %%
from sentence_transformers import SentenceTransformer
from sklearn.metrics.pairwise import cosine_similarity

# %%
# Load a pre-trained Sentence-BERT model
model = SentenceTransformer('all-MiniLM-L6-v2')
# Out:
# modules.json:   0%|          | 0.00/349 [00:00<?, ?B/s]
# config_sentence_transformers.json:   0%|          | 0.00/116 [00:00<?, ?B/s]
# README.md:   0%|          | 0.00/10.7k [00:00<?, ?B/s]
# sentence_bert_config.json:   0%|          | 0.00/53.0 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/612 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/90.9M [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/350 [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/232k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/466k [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/112 [00:00<?, ?B/s]
# 1_Pooling/config.json:   0%|          | 0.00/190 [00:00<?, ?B/s]

# %%
# Encode the comments to get their embeddings
embeddings_ref = model.encode(reference_comments)
embeddings_gen = model.encode(generated_comments)

# %%
# Compute cosine similarity for each pair
similarity_scores = cosine_similarity(embeddings_ref, embeddings_gen).diagonal()

# Calculate average similarity
average_similarity = similarity_scores.mean()



print(f"\nAverage Cosine Similarity: {average_similarity:.4f}")
# Out:
# Average Cosine Similarity: 0.3956

# %%
print(reference_comments[0])
print("__________")
print(generated_comments[0])
# Out:
# send a signal `signal.SIGUSR1` to the current process
# __________
# 1. os.kill() 2. os.getpid() 3. signal.SIGUSR1 The code above is a Python program that uses the os.kill() function to send a signal to the current process. The signal is specified by the signal.SIGUSR1 constant, which is defined in the signal module. The os.getpid() function returns the process ID of the current process, which is used to identify the process to be sent the signal. The os.kill() function takes two arguments:
