# %%
#python

# %%
# !pip install datasets pandas scikit-learn matplotlib torch
# !pip install -U bitsandbytes
# Out:
# Collecting datasets
#   Downloading datasets-3.2.0-py3-none-any.whl.metadata (20 kB)
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (2.2.2)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.10/dist-packages (1.5.2)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.10/dist-packages (3.8.0)
# Requirement already satisfied: torch in /usr/local/lib/python3.10/dist-packages (2.5.1+cu121)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from datasets) (3.16.1)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.10/dist-packages (from datasets) (1.26.4)
# Requirement already satisfied: pyarrow>=15.0.0 in /usr/local/lib/python3.10/dist-packages (from datasets) (17.0.0)
# Collecting dill<0.3.9,>=0.3.0 (from datasets)
#   Downloading dill-0.3.8-py3-none-any.whl.metadata (10 kB)
# Requirement already satisfied: requests>=2.32.2 in /usr/local/lib/python3.10/dist-packages (from datasets) (2.32.3)
# Requirement already satisfied: tqdm>=4.66.3 in /usr/local/lib/python3.10/dist-packages (from datasets) (4.66.6)
# Collecting xxhash (from datasets)
#   Downloading xxhash-3.5.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (12 kB)
# Collecting multiprocess<0.70.17 (from datasets)
#   Downloading multiprocess-0.70.16-py310-none-any.whl.metadata (7.2 kB)
# Collecting fsspec<=2024.9.0,>=2023.1.0 (from fsspec[http]<=2024.9.0,>=2023.1.0->datasets)
#   Downloading fsspec-2024.9.0-py3-none-any.whl.metadata (11 kB)
# Requirement already satisfied: aiohttp in /usr/local/lib/python3.10/dist-packages (from datasets) (3.11.10)
# Requirement already satisfied: huggingface-hub>=0.23.0 in /usr/local/lib/python3.10/dist-packages (from datasets) (0.26.5)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from datasets) (24.2)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from datasets) (6.0.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.10/dist-packages (from pandas) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.10/dist-packages (from pandas) (2024.2)
# Requirement already satisfied: scipy>=1.6.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn) (1.13.1)
# Requirement already satisfied: joblib>=1.2.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn) (1.4.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn) (3.5.0)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (4.55.2)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (1.4.7)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (11.0.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (3.2.0)
# Requirement already satisfied: typing-extensions>=4.8.0 in /usr/local/lib/python3.10/dist-packages (from torch) (4.12.2)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch) (3.4.2)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch) (3.1.4)
# Requirement already satisfied: sympy==1.13.1 in /usr/local/lib/python3.10/dist-packages (from torch) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from sympy==1.13.1->torch) (1.3.0)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (2.4.4)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (1.3.1)
# Requirement already satisfied: async-timeout<6.0,>=4.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (4.0.3)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (24.2.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (1.5.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (6.1.0)
# Requirement already satisfied: propcache>=0.2.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (0.2.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (1.18.3)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests>=2.32.2->datasets) (3.4.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests>=2.32.2->datasets) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests>=2.32.2->datasets) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests>=2.32.2->datasets) (2024.8.30)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch) (3.0.2)
# Downloading datasets-3.2.0-py3-none-any.whl (480 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 480.6/480.6 kB 29.2 MB/s eta 0:00:00
# Downloading dill-0.3.8-py3-none-any.whl (116 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 116.3/116.3 kB 11.0 MB/s eta 0:00:00
# Downloading fsspec-2024.9.0-py3-none-any.whl (179 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 179.3/179.3 kB 15.4 MB/s eta 0:00:00
# Downloading multiprocess-0.70.16-py310-none-any.whl (134 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 134.8/134.8 kB 12.6 MB/s eta 0:00:00
# Downloading xxhash-3.5.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (194 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 194.1/194.1 kB 18.3 MB/s eta 0:00:00
# Installing collected packages: xxhash, fsspec, dill, multiprocess, datasets
#   Attempting uninstall: fsspec
#     Found existing installation: fsspec 2024.10.0
#     Uninstalling fsspec-2024.10.0:
#       Successfully uninstalled fsspec-2024.10.0
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# gcsfs 2024.10.0 requires fsspec==2024.10.0, but you have fsspec 2024.9.0 which is incompatible.
# Successfully installed datasets-3.2.0 dill-0.3.8 fsspec-2024.9.0 multiprocess-0.70.16 xxhash-3.5.0
# Collecting bitsandbytes
#   Downloading bitsandbytes-0.45.0-py3-none-manylinux_2_24_x86_64.whl.metadata (2.9 kB)
# Requirement already satisfied: torch in /usr/local/lib/python3.10/dist-packages (from bitsandbytes) (2.5.1+cu121)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from bitsandbytes) (1.26.4)
# Requirement already satisfied: typing_extensions>=4.8.0 in /usr/local/lib/python3.10/dist-packages (from bitsandbytes) (4.12.2)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from torch->bitsandbytes) (3.16.1)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch->bitsandbytes) (3.4.2)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch->bitsandbytes) (3.1.4)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from torch->bitsandbytes) (2024.9.0)
# Requirement already satisfied: sympy==1.13.1 in /usr/local/lib/python3.10/dist-packages (from torch->bitsandbytes) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from sympy==1.13.1->torch->bitsandbytes) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch->bitsandbytes) (3.0.2)
# Downloading bitsandbytes-0.45.0-py3-none-manylinux_2_24_x86_64.whl (69.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 69.1/69.1 MB 8.7 MB/s eta 0:00:00
# Installing collected packages: bitsandbytes
# Successfully installed bitsandbytes-0.45.0

# %%
from datasets import load_dataset

# Step 2: Data Collection
# Specify the programming language for the dataset
language = "python"  # Choose from 'python', 'java', 'javascript', 'php', 'ruby', 'go'


# Load the dataset
dataset = load_dataset("code_search_net", language)
# Out:
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# README.md:   0%|          | 0.00/12.9k [00:00<?, ?B/s]
# code_search_net.py:   0%|          | 0.00/8.44k [00:00<?, ?B/s]
# The repository for code_search_net contains custom code which must be executed to correctly load the dataset. You can inspect the repository content at https://hf.co/datasets/code_search_net.
# You can avoid this prompt in future by passing the argument `trust_remote_code=True`.
#
# Do you wish to run the custom code? [y/N] y
# python.zip:   0%|          | 0.00/941M [00:00<?, ?B/s]
# Generating train split:   0%|          | 0/412178 [00:00<?, ? examples/s]
# Generating test split:   0%|          | 0/22176 [00:00<?, ? examples/s]
# Generating validation split:   0%|          | 0/23107 [00:00<?, ? examples/s]

# %%
# Explore the dataset
print(dataset)
# Out:
# DatasetDict({
#     train: Dataset({
#         features: ['repository_name', 'func_path_in_repository', 'func_name', 'whole_func_string', 'language', 'func_code_string', 'func_code_tokens', 'func_documentation_string', 'func_documentation_tokens', 'split_name', 'func_code_url'],
#         num_rows: 412178
#     })
#     test: Dataset({
#         features: ['repository_name', 'func_path_in_repository', 'func_name', 'whole_func_string', 'language', 'func_code_string', 'func_code_tokens', 'func_documentation_string', 'func_documentation_tokens', 'split_name', 'func_code_url'],
#         num_rows: 22176
#     })
#     validation: Dataset({
#         features: ['repository_name', 'func_path_in_repository', 'func_name', 'whole_func_string', 'language', 'func_code_string', 'func_code_tokens', 'func_documentation_string', 'func_documentation_tokens', 'split_name', 'func_code_url'],
#         num_rows: 23107
#     })
# })

# %%
train_df = dataset['train'].to_pandas()[['func_code_string','func_documentation_string']]
test_df = dataset['test'].to_pandas()[['func_code_string','func_documentation_string']]
validation_df = dataset['validation'].to_pandas()[['func_code_string','func_documentation_string']]

# %%
# Access the first example
first_example = train_df.iloc[0]
print("Docstring:\n", first_example['func_documentation_string'])
print()
print("Code:\n", first_example['func_code_string'])
# Out:
# Docstring:
#  Get a list of datetime sorted rows from a table in the database
#     :param dbconn: database connection
#     :param table_name: name of table in the database
#     :param uuid: optional uuid to pull from
#     :param column: optional column/field in the table to pull instead of rows
#     :returns: a list of tuples containing (datetime, row) pairs or (datetime, column) pairs if columns is specified.
#
# Code:
#  def get_datetime_sorted_rows(dbconn, table_name, uuid=None, column=None):
#     """
#     Get a list of datetime sorted rows from a table in the database
#     :param dbconn: database connection
#     :param table_name: name of table in the database
#     :param uuid: optional uuid to pull from
#     :param column: optional column/field in the table to pull instead of rows
#     :returns: a list of tuples containing (datetime, row) pairs or (datetime, column) pairs if columns is specified.
#     """
#     rows = get_rows(dbconn, table_name, uuid=uuid)
#     data = []
#     for r in rows:
#         dt = datetime.datetime.strptime(r['Time'], "%d/%m/%Y %H:%M:%S")
#         if column is None:
#             data.append((dt, r))
#         else:
#             data.append((dt, r[column]))
#     data.sort()
#
#     return data

# %%
# remove comment from code
import pandas as pd
import re


# Function to remove comments
def remove_comments(code):
    code = re.sub(r'#.*', '', code)  # Remove single-line comments
    code = re.sub(r'""".*?"""|\'\'\'.*?\'\'\'', '', code, flags=re.DOTALL)  # Remove multi-line comments
    return code

# Apply the function to the column
train_df['func_code_string'] = train_df['func_code_string'].apply(remove_comments)
test_df['func_code_string'] = test_df['func_code_string'].apply(remove_comments)
validation_df['func_code_string'] = validation_df['func_code_string'].apply(remove_comments)

# %%
# Access the first example
first_example = train_df.iloc[0]
print("Docstring:\n", first_example['func_documentation_string'])
print()
print("Code:\n", first_example['func_code_string'])
# Out:
# Docstring:
#  Get a list of datetime sorted rows from a table in the database
#     :param dbconn: database connection
#     :param table_name: name of table in the database
#     :param uuid: optional uuid to pull from
#     :param column: optional column/field in the table to pull instead of rows
#     :returns: a list of tuples containing (datetime, row) pairs or (datetime, column) pairs if columns is specified.
#
# Code:
#  def get_datetime_sorted_rows(dbconn, table_name, uuid=None, column=None):
#
#     rows = get_rows(dbconn, table_name, uuid=uuid)
#     data = []
#     for r in rows:
#         dt = datetime.datetime.strptime(r['Time'], "%d/%m/%Y %H:%M:%S")
#         if column is None:
#             data.append((dt, r))
#         else:
#             data.append((dt, r[column]))
#     data.sort()
#
#     return data

# %%
#remove any non-english comments.
# From https://stackoverflow.com/a/27084708/5768407

def isASCII(s):
    try:
        s.encode(encoding='utf-8').decode('ascii')
    except UnicodeDecodeError:
        return False
    else:
        return True

train_df = train_df[train_df['func_documentation_string'].apply(lambda x: isASCII(x))]
test_df = test_df[test_df['func_documentation_string'].apply(lambda x: isASCII(x))]
validation_df = validation_df[validation_df['func_documentation_string'].apply(lambda x: isASCII(x))]

# %%
# remove any empty comments or duplicate comments
train_df = train_df[~(train_df['func_documentation_string'] == '')]
test_df = test_df[~(test_df['func_documentation_string'] == '')]
validation_df = validation_df[~(validation_df['func_documentation_string'] == '')]

# %%
train_df = train_df[~train_df['func_documentation_string'].duplicated()]
test_df = test_df[~test_df['func_documentation_string'].duplicated()]
validation_df = validation_df[~validation_df['func_documentation_string'].duplicated()]

# %%
len(train_df), len(test_df), len(validation_df)
# Out:
# (385782, 21342, 21905)

# %%
import pandas as pd
import matplotlib.pyplot as plt
from datasets import load_dataset
from sklearn.model_selection import train_test_split
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity
import numpy as np

# %%
from huggingface_hub import snapshot_download, login

# %%
login(token="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")

# %%
import torch
import re
from transformers import AutoTokenizer, AutoModelForCausalLM

# Load the tokenizer and model
model_name = "meta-llama/Llama-3.2-3B"
tokenizer = AutoTokenizer.from_pretrained(model_name)
model = AutoModelForCausalLM.from_pretrained(
    model_name,
    device_map="auto",
    torch_dtype="auto",
    load_in_8bit=True  # Optional: Use 8-bit precision to save memory
)
# Out:
# The cache for model files in Transformers v4.22.0 has been updated. Migrating your old cache. This is a one-time only operation. You can interrupt this and resume the migration later on by calling `transformers.utils.move_cache()`.
# 0it [00:00, ?it/s]
# tokenizer_config.json:   0%|          | 0.00/50.5k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/9.09M [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/301 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/844 [00:00<?, ?B/s]
# The `load_in_4bit` and `load_in_8bit` arguments are deprecated and will be removed in the future versions. Please, pass a `BitsAndBytesConfig` object in `quantization_config` argument instead.
# model.safetensors.index.json:   0%|          | 0.00/20.9k [00:00<?, ?B/s]
# Downloading shards:   0%|          | 0/2 [00:00<?, ?it/s]
# model-00001-of-00002.safetensors:   0%|          | 0.00/4.97G [00:00<?, ?B/s]
# model-00002-of-00002.safetensors:   0%|          | 0.00/1.46G [00:00<?, ?B/s]
# Loading checkpoint shards:   0%|          | 0/2 [00:00<?, ?it/s]
# generation_config.json:   0%|          | 0.00/185 [00:00<?, ?B/s]

# %%
model.device
# Out:
# device(type='cuda', index=0)

# %%
def generate_zero_shot_documentation(model, tokenizer, code_snippet, max_length=150):

    example_code = """
    def add(a, b):
    return a + b
"""

    example_doc = """
    Adds two numbers and returns the result.

"""
    prompt = f"""You are an assistant that generates documentation for Python functions.

Example:

Function:
{example_code}
Documentation:{example_doc}

Now, generate documentation for the following function:

Function:
{code_snippet}

Documentation:"""


    inputs = tokenizer(prompt, return_tensors="pt").to(model.device)
    outputs = model.generate(
    **inputs,
    max_new_tokens=max_length,
    temperature=0.0,  # Deterministic output
    top_p=0.95,
    do_sample=False,  # Greedy decoding
    eos_token_id=tokenizer.eos_token_id)

    documentation = tokenizer.decode(outputs[0], skip_special_tokens=True)
    doc_start = documentation.find("Documentation:") + len("Documentation:")

    full_doc = documentation[doc_start:].strip()

    # Extract the first two sentences
    doc = full_doc.replace('"""', '').replace('#', '').strip()
    doc =  " ".join(doc.split())
    return doc

# %%
import re
from tqdm import tqdm
import pandas as pd

# %%
fraction = 1/40
sampled_test_df = test_df.sample(frac=fraction, random_state=42)
print(len(sampled_test_df))
# Out:
# 534

# %%
generated_comments = []
reference_comments = []

# Iterate over the test set
for _, row in tqdm(sampled_test_df.iterrows(), total=sampled_test_df.shape[0]):
    code = row['func_code_string']
    reference = row['func_documentation_string']

    generated_comments.append(generate_zero_shot_documentation(model, tokenizer, code, max_length=150))
    reference_comments.append(reference)
# Out:
#   0%|          | 0/534 [00:00<?, ?it/s]/usr/local/lib/python3.10/dist-packages/transformers/generation/configuration_utils.py:590: UserWarning: `do_sample` is set to `False`. However, `temperature` is set to `0.0` -- this flag is only used in sample-based generation modes. You should set `do_sample=True` or unset `temperature`.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/transformers/generation/configuration_utils.py:595: UserWarning: `do_sample` is set to `False`. However, `top_p` is set to `0.95` -- this flag is only used in sample-based generation modes. You should set `do_sample=True` or unset `top_p`.
#   warnings.warn(
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# /usr/local/lib/python3.10/dist-packages/bitsandbytes/autograd/_functions.py:315: UserWarning: MatMul8bitLt: inputs will be cast from torch.bfloat16 to float16 during quantization
#   warnings.warn(f"MatMul8bitLt: inputs will be cast from {A.dtype} to float16 during quantization")
#   0%|          | 1/534 [00:02<19:34,  2.20s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#   0%|          | 2/534 [00:02<08:57,  1.01s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#   1%|          | 3/534 [00:02<05:33,  1.59it/s]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#   1%|          | 4/534 [00:02<03:56,  2.24it/s]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#   1%|          | 5/534 [00:02<03:01,  2.91it/s]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#   1%|          | 6/534 [00:03<02:33,  3.43it/s]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#   1%|▏         | 7/534 [00:03<02:45,  3.19it/s]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#   1%|▏         | 8/534 [00:03<02:20,  3.73it/s]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#   2%|▏         | 9/534 [00:03<02:04,  4.22it/s]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#   2%|▏         | 10/534 [00:03<01:53,  4.62it/s]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#   2%|▏         | 11/534 [00:04<01:43,  5.03it/s]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#   2%|▏         | 12/534 [00:04<01:37,  5.33it/s]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#   2%|▏         | 13/534 [00:04<01:35,  5.48it/s]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#   3%|▎         | 14/534 [00:04<01:34,  5.49it/s]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#   3%|▎         | 15/534 [00:04<01:31,  5.66it/s]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#   3%|▎         | 16/534 [00:04<01:38,  5.28it/s]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#   3%|▎         | 17/534 [00:23<50:10,  5.82s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#   3%|▎         | 18/534 [00:24<35:32,  4.13s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#   4%|▎         | 19/534 [00:42<1:11:50,  8.37s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#   4%|▎         | 20/534 [00:42<50:38,  5.91s/it]  Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#   4%|▍         | 21/534 [00:42<35:59,  4.21s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#   4%|▍         | 22/534 [00:43<25:43,  3.01s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#   4%|▍         | 23/534 [00:43<18:29,  2.17s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#   4%|▍         | 24/534 [00:43<13:26,  1.58s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#   5%|▍         | 25/534 [00:43<09:58,  1.18s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#   5%|▍         | 26/534 [00:43<07:27,  1.13it/s]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#   5%|▌         | 27/534 [00:59<44:29,  5.27s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#   5%|▌         | 28/534 [00:59<31:31,  3.74s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#   5%|▌         | 29/534 [00:59<22:29,  2.67s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#   6%|▌         | 30/534 [00:59<16:08,  1.92s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#   6%|▌         | 31/534 [01:00<11:43,  1.40s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#   6%|▌         | 32/534 [01:00<08:36,  1.03s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#   6%|▌         | 33/534 [01:00<06:26,  1.30it/s]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#   6%|▋         | 34/534 [01:00<04:59,  1.67it/s]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#   7%|▋         | 35/534 [01:00<03:53,  2.13it/s]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#   7%|▋         | 36/534 [01:00<03:08,  2.64it/s]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#   7%|▋         | 37/534 [01:19<48:44,  5.89s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#   7%|▋         | 38/534 [01:19<34:29,  4.17s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#   7%|▋         | 39/534 [01:20<24:33,  2.98s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#   7%|▋         | 40/534 [01:20<17:35,  2.14s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#   8%|▊         | 41/534 [01:20<12:42,  1.55s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#   8%|▊         | 42/534 [01:20<09:24,  1.15s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#   8%|▊         | 43/534 [01:20<07:00,  1.17it/s]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#   8%|▊         | 44/534 [01:20<05:17,  1.54it/s]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#   8%|▊         | 45/534 [01:21<04:07,  1.97it/s]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#   9%|▊         | 46/534 [01:21<03:18,  2.46it/s]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#   9%|▉         | 47/534 [01:21<02:50,  2.86it/s]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#   9%|▉         | 48/534 [01:21<02:33,  3.16it/s]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#   9%|▉         | 49/534 [01:21<02:17,  3.51it/s]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#   9%|▉         | 50/534 [01:22<02:10,  3.70it/s]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  10%|▉         | 51/534 [01:22<02:01,  3.96it/s]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  10%|▉         | 52/534 [01:22<01:55,  4.18it/s]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  10%|▉         | 53/534 [01:22<01:54,  4.21it/s]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  10%|█         | 54/534 [01:23<01:53,  4.21it/s]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  10%|█         | 55/534 [01:23<01:52,  4.27it/s]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  10%|█         | 56/534 [01:23<01:51,  4.29it/s]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  11%|█         | 57/534 [01:23<01:51,  4.29it/s]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  11%|█         | 58/534 [01:23<01:50,  4.32it/s]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  11%|█         | 59/534 [01:32<22:00,  2.78s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  11%|█         | 60/534 [01:32<15:45,  1.99s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  11%|█▏        | 61/534 [01:33<11:25,  1.45s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  12%|█▏        | 62/534 [01:33<08:22,  1.07s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  12%|█▏        | 63/534 [01:33<06:21,  1.23it/s]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  12%|█▏        | 64/534 [01:33<04:52,  1.61it/s]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  12%|█▏        | 65/534 [01:33<04:11,  1.87it/s]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  12%|█▏        | 66/534 [01:34<03:19,  2.35it/s]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  13%|█▎        | 67/534 [01:52<44:48,  5.76s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  13%|█▎        | 68/534 [01:52<31:42,  4.08s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  13%|█▎        | 69/534 [01:52<22:35,  2.92s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  13%|█▎        | 70/534 [01:52<16:10,  2.09s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  13%|█▎        | 71/534 [01:53<11:43,  1.52s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  13%|█▎        | 72/534 [01:53<08:49,  1.15s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  14%|█▎        | 73/534 [01:53<06:32,  1.17it/s]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  14%|█▍        | 74/534 [01:53<05:01,  1.53it/s]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  14%|█▍        | 75/534 [01:53<04:00,  1.91it/s]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  14%|█▍        | 76/534 [01:54<03:10,  2.41it/s]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  14%|█▍        | 77/534 [01:54<02:35,  2.94it/s]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  15%|█▍        | 78/534 [01:54<02:10,  3.48it/s]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  15%|█▍        | 79/534 [01:54<01:56,  3.89it/s]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  15%|█▍        | 80/534 [01:54<01:44,  4.36it/s]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  15%|█▌        | 81/534 [01:54<01:39,  4.57it/s]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  15%|█▌        | 82/534 [01:55<01:34,  4.80it/s]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  16%|█▌        | 83/534 [01:55<01:50,  4.07it/s]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  16%|█▌        | 84/534 [01:55<01:46,  4.25it/s]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  16%|█▌        | 85/534 [01:55<01:37,  4.62it/s]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  16%|█▌        | 86/534 [01:55<01:32,  4.82it/s]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  16%|█▋        | 87/534 [01:56<01:26,  5.14it/s]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  16%|█▋        | 88/534 [01:56<01:24,  5.29it/s]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  17%|█▋        | 89/534 [01:56<01:22,  5.39it/s]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  17%|█▋        | 90/534 [01:56<01:42,  4.35it/s]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  17%|█▋        | 91/534 [01:57<01:33,  4.74it/s]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  17%|█▋        | 92/534 [01:58<03:20,  2.21it/s]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  17%|█▋        | 93/534 [01:58<02:43,  2.69it/s]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  18%|█▊        | 94/534 [01:58<02:17,  3.19it/s]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  18%|█▊        | 95/534 [01:58<01:59,  3.68it/s]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  18%|█▊        | 96/534 [01:58<01:49,  4.01it/s]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  18%|█▊        | 97/534 [01:58<01:38,  4.44it/s]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  18%|█▊        | 98/534 [02:18<42:49,  5.89s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  19%|█▊        | 99/534 [02:18<30:19,  4.18s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  19%|█▊        | 100/534 [02:18<21:33,  2.98s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  19%|█▉        | 101/534 [02:19<16:30,  2.29s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  19%|█▉        | 102/534 [02:19<11:53,  1.65s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  19%|█▉        | 103/534 [02:19<08:42,  1.21s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  19%|█▉        | 104/534 [02:19<06:27,  1.11it/s]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  20%|█▉        | 105/534 [02:19<04:52,  1.47it/s]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  20%|█▉        | 106/534 [02:19<03:45,  1.90it/s]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  20%|██        | 107/534 [02:20<02:59,  2.38it/s]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  20%|██        | 108/534 [02:20<02:31,  2.81it/s]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  20%|██        | 109/534 [02:38<40:18,  5.69s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  21%|██        | 110/534 [02:39<29:17,  4.14s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  21%|██        | 111/534 [02:57<58:43,  8.33s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  21%|██        | 112/534 [02:57<41:21,  5.88s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  21%|██        | 113/534 [02:57<29:14,  4.17s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  21%|██▏       | 114/534 [02:57<20:46,  2.97s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  22%|██▏       | 115/534 [02:57<14:52,  2.13s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  22%|██▏       | 116/534 [02:57<10:50,  1.56s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  22%|██▏       | 117/534 [02:59<10:15,  1.48s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  22%|██▏       | 118/534 [02:59<07:38,  1.10s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  22%|██▏       | 119/534 [02:59<05:42,  1.21it/s]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  22%|██▏       | 120/534 [02:59<04:19,  1.60it/s]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  23%|██▎       | 121/534 [03:18<40:55,  5.95s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  23%|██▎       | 122/534 [03:18<28:57,  4.22s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  23%|██▎       | 123/534 [03:18<20:34,  3.00s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  23%|██▎       | 124/534 [03:37<53:59,  7.90s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  23%|██▎       | 125/534 [03:38<38:02,  5.58s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  24%|██▎       | 126/534 [03:38<27:19,  4.02s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  24%|██▍       | 127/534 [03:38<19:27,  2.87s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  24%|██▍       | 128/534 [03:58<53:07,  7.85s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  24%|██▍       | 129/534 [03:58<37:30,  5.56s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  24%|██▍       | 130/534 [03:58<26:32,  3.94s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  25%|██▍       | 131/534 [04:16<54:58,  8.18s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  25%|██▍       | 132/534 [04:16<38:48,  5.79s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  25%|██▍       | 133/534 [04:16<27:29,  4.11s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  25%|██▌       | 134/534 [04:17<19:40,  2.95s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  25%|██▌       | 135/534 [04:17<14:10,  2.13s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  25%|██▌       | 136/534 [04:36<46:53,  7.07s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  26%|██▌       | 137/534 [04:54<1:08:56, 10.42s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  26%|██▌       | 138/534 [04:54<48:28,  7.34s/it]  Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  26%|██▌       | 139/534 [05:12<1:10:13, 10.67s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  26%|██▌       | 140/534 [05:13<49:24,  7.52s/it]  Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  26%|██▋       | 141/534 [05:13<34:54,  5.33s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  27%|██▋       | 142/534 [05:13<24:41,  3.78s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  27%|██▋       | 143/534 [05:14<19:39,  3.02s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  27%|██▋       | 144/534 [05:14<14:05,  2.17s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  27%|██▋       | 145/534 [05:15<10:10,  1.57s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  27%|██▋       | 146/534 [05:15<07:25,  1.15s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  28%|██▊       | 147/534 [05:15<05:30,  1.17it/s]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  28%|██▊       | 148/534 [05:15<04:13,  1.52it/s]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  28%|██▊       | 149/534 [05:15<03:16,  1.96it/s]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  28%|██▊       | 150/534 [05:15<02:36,  2.45it/s]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  28%|██▊       | 151/534 [05:16<02:09,  2.97it/s]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  28%|██▊       | 152/534 [05:16<02:01,  3.14it/s]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  29%|██▊       | 153/534 [05:16<01:45,  3.60it/s]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  29%|██▉       | 154/534 [05:16<01:33,  4.07it/s]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  29%|██▉       | 155/534 [05:16<01:26,  4.39it/s]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  29%|██▉       | 156/534 [05:17<01:21,  4.61it/s]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  29%|██▉       | 157/534 [05:17<01:15,  5.01it/s]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  30%|██▉       | 158/534 [05:17<01:10,  5.36it/s]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  30%|██▉       | 159/534 [05:17<01:25,  4.37it/s]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  30%|██▉       | 160/534 [05:17<01:18,  4.74it/s]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  30%|███       | 161/534 [05:18<01:13,  5.06it/s]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  30%|███       | 162/534 [05:18<01:09,  5.31it/s]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  31%|███       | 163/534 [05:18<01:14,  4.99it/s]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  31%|███       | 164/534 [05:37<35:56,  5.83s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  31%|███       | 165/534 [05:37<25:26,  4.14s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  31%|███       | 166/534 [05:37<18:06,  2.95s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  31%|███▏      | 167/534 [05:37<12:56,  2.12s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  31%|███▏      | 168/534 [05:38<09:20,  1.53s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  32%|███▏      | 169/534 [05:38<06:50,  1.13s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  32%|███▏      | 170/534 [05:38<05:07,  1.18it/s]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  32%|███▏      | 171/534 [05:38<03:53,  1.55it/s]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  32%|███▏      | 172/534 [05:38<03:04,  1.96it/s]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  32%|███▏      | 173/534 [05:39<02:28,  2.44it/s]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  33%|███▎      | 174/534 [05:39<02:00,  2.98it/s]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  33%|███▎      | 175/534 [05:39<01:47,  3.33it/s]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  33%|███▎      | 176/534 [05:39<01:34,  3.78it/s]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  33%|███▎      | 177/534 [05:39<01:23,  4.26it/s]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  33%|███▎      | 178/534 [05:39<01:16,  4.66it/s]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  34%|███▎      | 179/534 [05:40<01:13,  4.81it/s]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  34%|███▎      | 180/534 [05:40<01:09,  5.08it/s]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  34%|███▍      | 181/534 [05:40<01:07,  5.22it/s]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  34%|███▍      | 182/534 [05:40<01:05,  5.34it/s]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  34%|███▍      | 183/534 [05:40<01:03,  5.53it/s]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  34%|███▍      | 184/534 [05:40<01:02,  5.62it/s]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  35%|███▍      | 185/534 [05:41<01:06,  5.29it/s]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  35%|███▍      | 186/534 [05:41<01:04,  5.39it/s]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  35%|███▌      | 187/534 [05:41<01:03,  5.44it/s]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  35%|███▌      | 188/534 [05:41<01:05,  5.28it/s]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  35%|███▌      | 189/534 [05:41<01:04,  5.37it/s]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  36%|███▌      | 190/534 [05:42<01:05,  5.27it/s]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  36%|███▌      | 191/534 [05:42<01:03,  5.40it/s]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  36%|███▌      | 192/534 [05:42<01:03,  5.43it/s]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  36%|███▌      | 193/534 [05:42<01:02,  5.46it/s]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  36%|███▋      | 194/534 [06:01<33:02,  5.83s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  37%|███▋      | 195/534 [06:01<23:23,  4.14s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  37%|███▋      | 196/534 [06:02<16:38,  2.95s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  37%|███▋      | 197/534 [06:02<11:53,  2.12s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  37%|███▋      | 198/534 [06:07<16:43,  2.99s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  37%|███▋      | 199/534 [06:26<43:09,  7.73s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  37%|███▋      | 200/534 [06:26<30:23,  5.46s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  38%|███▊      | 201/534 [06:26<21:33,  3.89s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  38%|███▊      | 202/534 [06:26<15:21,  2.78s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  38%|███▊      | 203/534 [06:44<40:44,  7.39s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  38%|███▊      | 204/534 [06:44<28:42,  5.22s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  38%|███▊      | 205/534 [06:45<20:21,  3.71s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  39%|███▊      | 206/534 [06:45<14:30,  2.65s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  39%|███▉      | 207/534 [06:45<10:25,  1.91s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  39%|███▉      | 208/534 [06:45<07:34,  1.39s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  39%|███▉      | 209/534 [06:45<05:33,  1.02s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  39%|███▉      | 210/534 [06:45<04:09,  1.30it/s]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  40%|███▉      | 211/534 [06:46<03:11,  1.69it/s]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  40%|███▉      | 212/534 [06:46<02:29,  2.15it/s]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  40%|███▉      | 213/534 [06:46<02:02,  2.61it/s]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  40%|████      | 214/534 [06:46<01:41,  3.14it/s]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  40%|████      | 215/534 [06:46<01:26,  3.67it/s]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  40%|████      | 216/534 [06:47<01:19,  3.98it/s]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  41%|████      | 217/534 [06:47<01:12,  4.40it/s]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  41%|████      | 218/534 [06:47<01:08,  4.64it/s]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  41%|████      | 219/534 [06:47<01:04,  4.87it/s]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  41%|████      | 220/534 [06:47<01:01,  5.14it/s]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  41%|████▏     | 221/534 [06:47<01:02,  4.99it/s]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  42%|████▏     | 222/534 [06:48<01:05,  4.74it/s]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  42%|████▏     | 223/534 [06:48<01:04,  4.79it/s]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  42%|████▏     | 224/534 [06:48<01:06,  4.66it/s]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  42%|████▏     | 225/534 [06:48<01:04,  4.76it/s]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  42%|████▏     | 226/534 [06:49<01:08,  4.46it/s]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  43%|████▎     | 227/534 [06:49<01:10,  4.35it/s]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  43%|████▎     | 228/534 [06:49<01:12,  4.23it/s]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  43%|████▎     | 229/534 [06:49<01:11,  4.27it/s]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  43%|████▎     | 230/534 [06:50<01:10,  4.28it/s]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  43%|████▎     | 231/534 [06:50<01:11,  4.26it/s]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  43%|████▎     | 232/534 [06:50<01:09,  4.33it/s]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  44%|████▎     | 233/534 [06:50<01:06,  4.53it/s]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  44%|████▍     | 234/534 [06:50<01:09,  4.34it/s]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  44%|████▍     | 235/534 [06:51<01:03,  4.70it/s]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  44%|████▍     | 236/534 [06:51<00:59,  4.98it/s]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  44%|████▍     | 237/534 [06:51<01:18,  3.80it/s]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  45%|████▍     | 238/534 [06:51<01:09,  4.28it/s]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  45%|████▍     | 239/534 [06:52<01:08,  4.29it/s]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  45%|████▍     | 240/534 [06:52<01:03,  4.64it/s]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  45%|████▌     | 241/534 [06:52<01:01,  4.80it/s]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  45%|████▌     | 242/534 [06:52<00:58,  5.01it/s]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  46%|████▌     | 243/534 [06:52<00:54,  5.30it/s]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  46%|████▌     | 244/534 [06:52<00:53,  5.43it/s]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  46%|████▌     | 245/534 [06:53<00:53,  5.41it/s]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  46%|████▌     | 246/534 [06:53<00:52,  5.48it/s]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  46%|████▋     | 247/534 [06:53<00:52,  5.51it/s]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  46%|████▋     | 248/534 [06:53<00:50,  5.71it/s]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  47%|████▋     | 249/534 [06:53<00:49,  5.80it/s]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  47%|████▋     | 250/534 [06:54<00:48,  5.84it/s]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  47%|████▋     | 251/534 [06:54<00:47,  5.90it/s]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  47%|████▋     | 252/534 [06:54<00:47,  5.90it/s]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  47%|████▋     | 253/534 [06:54<00:55,  5.07it/s]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  48%|████▊     | 254/534 [06:54<00:52,  5.30it/s]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  48%|████▊     | 255/534 [06:54<00:50,  5.52it/s]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  48%|████▊     | 256/534 [06:55<00:49,  5.67it/s]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  48%|████▊     | 257/534 [06:55<00:50,  5.46it/s]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  48%|████▊     | 258/534 [06:55<00:51,  5.40it/s]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  49%|████▊     | 259/534 [06:55<00:50,  5.42it/s]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  49%|████▊     | 260/534 [06:55<00:53,  5.08it/s]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  49%|████▉     | 261/534 [07:14<26:02,  5.72s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  49%|████▉     | 262/534 [07:14<18:28,  4.08s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  49%|████▉     | 263/534 [07:15<13:13,  2.93s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  49%|████▉     | 264/534 [07:15<09:33,  2.13s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  50%|████▉     | 265/534 [07:15<07:02,  1.57s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  50%|████▉     | 266/534 [07:15<05:09,  1.16s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  50%|█████     | 267/534 [07:15<03:50,  1.16it/s]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  50%|█████     | 268/534 [07:16<02:55,  1.52it/s]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  50%|█████     | 269/534 [07:16<02:15,  1.96it/s]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  51%|█████     | 270/534 [07:16<01:49,  2.40it/s]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  51%|█████     | 271/534 [07:16<01:47,  2.45it/s]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  51%|█████     | 272/534 [07:17<01:29,  2.94it/s]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  51%|█████     | 273/534 [07:17<01:27,  3.00it/s]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  51%|█████▏    | 274/534 [07:17<01:14,  3.49it/s]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  51%|█████▏    | 275/534 [07:17<01:05,  3.94it/s]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  52%|█████▏    | 276/534 [07:17<00:58,  4.40it/s]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  52%|█████▏    | 277/534 [07:18<00:55,  4.61it/s]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  52%|█████▏    | 278/534 [07:18<00:51,  4.97it/s]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  52%|█████▏    | 279/534 [07:18<00:48,  5.27it/s]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  52%|█████▏    | 280/534 [07:18<00:47,  5.35it/s]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  53%|█████▎    | 281/534 [07:18<00:45,  5.51it/s]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  53%|█████▎    | 282/534 [07:18<00:44,  5.68it/s]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  53%|█████▎    | 283/534 [07:19<00:44,  5.60it/s]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  53%|█████▎    | 284/534 [07:19<00:44,  5.61it/s]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  53%|█████▎    | 285/534 [07:19<00:47,  5.26it/s]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  54%|█████▎    | 286/534 [07:19<00:46,  5.32it/s]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  54%|█████▎    | 287/534 [07:19<00:45,  5.49it/s]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  54%|█████▍    | 288/534 [07:20<00:44,  5.55it/s]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  54%|█████▍    | 289/534 [07:38<23:18,  5.71s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  54%|█████▍    | 290/534 [07:38<16:31,  4.07s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  54%|█████▍    | 291/534 [07:39<11:57,  2.95s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  55%|█████▍    | 292/534 [07:39<08:38,  2.14s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  55%|█████▍    | 293/534 [07:39<06:20,  1.58s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  55%|█████▌    | 294/534 [07:39<04:43,  1.18s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  55%|█████▌    | 295/534 [07:40<03:45,  1.06it/s]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  55%|█████▌    | 296/534 [07:40<02:50,  1.40it/s]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  56%|█████▌    | 297/534 [07:40<02:16,  1.73it/s]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  56%|█████▌    | 298/534 [07:40<01:47,  2.20it/s]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  56%|█████▌    | 299/534 [07:41<01:31,  2.57it/s]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  56%|█████▌    | 300/534 [07:41<01:16,  3.05it/s]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  56%|█████▋    | 301/534 [07:41<01:22,  2.83it/s]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  57%|█████▋    | 302/534 [07:42<01:12,  3.22it/s]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  57%|█████▋    | 303/534 [07:42<01:03,  3.64it/s]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  57%|█████▋    | 304/534 [07:42<00:56,  4.09it/s]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  57%|█████▋    | 305/534 [07:42<00:52,  4.36it/s]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  57%|█████▋    | 306/534 [08:00<21:08,  5.56s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  57%|█████▋    | 307/534 [08:00<14:57,  3.96s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  58%|█████▊    | 308/534 [08:00<10:38,  2.83s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  58%|█████▊    | 309/534 [08:01<07:36,  2.03s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  58%|█████▊    | 310/534 [08:01<05:32,  1.49s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  58%|█████▊    | 311/534 [08:01<04:24,  1.19s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  58%|█████▊    | 312/534 [08:02<03:16,  1.13it/s]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  59%|█████▊    | 313/534 [08:02<02:28,  1.49it/s]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  59%|█████▉    | 314/534 [08:02<01:56,  1.89it/s]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  59%|█████▉    | 315/534 [08:02<01:37,  2.25it/s]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  59%|█████▉    | 316/534 [08:02<01:24,  2.58it/s]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  59%|█████▉    | 317/534 [08:03<01:14,  2.93it/s]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  60%|█████▉    | 318/534 [08:03<01:05,  3.30it/s]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  60%|█████▉    | 319/534 [08:03<00:59,  3.60it/s]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  60%|█████▉    | 320/534 [08:03<00:56,  3.78it/s]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  60%|██████    | 321/534 [08:04<00:55,  3.85it/s]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  60%|██████    | 322/534 [08:22<20:09,  5.71s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  60%|██████    | 323/534 [08:40<33:13,  9.45s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  61%|██████    | 324/534 [08:40<23:22,  6.68s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  61%|██████    | 325/534 [08:59<35:51, 10.29s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  61%|██████    | 326/534 [08:59<25:10,  7.26s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  61%|██████    | 327/534 [08:59<17:42,  5.13s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  61%|██████▏   | 328/534 [09:00<12:34,  3.66s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  62%|██████▏   | 329/534 [09:00<08:59,  2.63s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  62%|██████▏   | 330/534 [09:00<06:28,  1.90s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  62%|██████▏   | 331/534 [09:00<04:41,  1.39s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  62%|██████▏   | 332/534 [09:00<03:26,  1.02s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  62%|██████▏   | 333/534 [09:01<02:35,  1.29it/s]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  63%|██████▎   | 334/534 [09:01<01:59,  1.68it/s]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  63%|██████▎   | 335/534 [09:01<01:36,  2.06it/s]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  63%|██████▎   | 336/534 [09:01<01:17,  2.56it/s]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  63%|██████▎   | 337/534 [09:01<01:04,  3.04it/s]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  63%|██████▎   | 338/534 [09:20<19:19,  5.92s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  63%|██████▎   | 339/534 [09:21<13:43,  4.22s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  64%|██████▎   | 340/534 [09:21<09:43,  3.01s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  64%|██████▍   | 341/534 [09:21<06:56,  2.16s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  64%|██████▍   | 342/534 [09:21<05:00,  1.56s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  64%|██████▍   | 343/534 [09:21<03:38,  1.15s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  64%|██████▍   | 344/534 [09:22<02:43,  1.16it/s]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  65%|██████▍   | 345/534 [09:40<19:19,  6.14s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  65%|██████▍   | 346/534 [09:40<13:37,  4.35s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  65%|██████▍   | 347/534 [09:40<09:38,  3.10s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  65%|██████▌   | 348/534 [09:40<06:52,  2.22s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  65%|██████▌   | 349/534 [09:41<04:57,  1.61s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  66%|██████▌   | 350/534 [09:41<03:37,  1.18s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  66%|██████▌   | 351/534 [09:41<02:41,  1.13it/s]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  66%|██████▌   | 352/534 [09:41<02:02,  1.48it/s]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  66%|██████▌   | 353/534 [09:41<01:34,  1.91it/s]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  66%|██████▋   | 354/534 [09:42<01:15,  2.39it/s]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  66%|██████▋   | 355/534 [09:42<01:03,  2.84it/s]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  67%|██████▋   | 356/534 [09:42<00:53,  3.32it/s]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  67%|██████▋   | 357/534 [09:42<00:47,  3.73it/s]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  67%|██████▋   | 358/534 [09:42<00:42,  4.16it/s]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  67%|██████▋   | 359/534 [09:43<00:45,  3.87it/s]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  67%|██████▋   | 360/534 [09:43<00:40,  4.25it/s]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  68%|██████▊   | 361/534 [09:43<00:42,  4.07it/s]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  68%|██████▊   | 362/534 [09:43<00:38,  4.45it/s]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  68%|██████▊   | 363/534 [10:03<17:01,  5.98s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  68%|██████▊   | 364/534 [10:03<12:01,  4.24s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  68%|██████▊   | 365/534 [10:03<08:32,  3.03s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  69%|██████▊   | 366/534 [10:03<06:05,  2.17s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  69%|██████▊   | 367/534 [10:03<04:23,  1.58s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  69%|██████▉   | 368/534 [10:04<03:12,  1.16s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  69%|██████▉   | 369/534 [10:04<02:22,  1.16it/s]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  69%|██████▉   | 370/534 [10:04<01:47,  1.52it/s]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  69%|██████▉   | 371/534 [10:04<01:24,  1.94it/s]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  70%|██████▉   | 372/534 [10:04<01:08,  2.35it/s]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  70%|██████▉   | 373/534 [10:05<00:57,  2.81it/s]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  70%|███████   | 374/534 [10:05<00:47,  3.34it/s]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  70%|███████   | 375/534 [10:05<00:42,  3.77it/s]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  70%|███████   | 376/534 [10:05<00:39,  3.96it/s]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  71%|███████   | 377/534 [10:05<00:35,  4.39it/s]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  71%|███████   | 378/534 [10:05<00:33,  4.71it/s]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  71%|███████   | 379/534 [10:06<00:30,  5.00it/s]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  71%|███████   | 380/534 [10:06<00:29,  5.27it/s]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  71%|███████▏  | 381/534 [10:06<00:31,  4.91it/s]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  72%|███████▏  | 382/534 [10:06<00:36,  4.13it/s]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  72%|███████▏  | 383/534 [10:07<00:36,  4.12it/s]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  72%|███████▏  | 384/534 [10:07<00:33,  4.45it/s]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  72%|███████▏  | 385/534 [10:07<00:31,  4.74it/s]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  72%|███████▏  | 386/534 [10:07<00:29,  5.01it/s]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  72%|███████▏  | 387/534 [10:07<00:28,  5.08it/s]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  73%|███████▎  | 388/534 [10:27<14:28,  5.95s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  73%|███████▎  | 389/534 [10:27<10:12,  4.23s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  73%|███████▎  | 390/534 [10:27<07:13,  3.01s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  73%|███████▎  | 391/534 [10:27<05:09,  2.17s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  73%|███████▎  | 392/534 [10:27<03:42,  1.57s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# ...
#  75%|███████▌  | 402/534 [10:32<00:38,  3.44it/s]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  75%|███████▌  | 403/534 [10:32<00:33,  3.91it/s]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  76%|███████▌  | 404/534 [10:32<00:30,  4.32it/s]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  76%|███████▌  | 405/534 [10:33<00:28,  4.54it/s]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  76%|███████▌  | 406/534 [10:33<00:26,  4.89it/s]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  76%|███████▌  | 407/534 [10:33<00:26,  4.88it/s]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  76%|███████▋  | 408/534 [10:33<00:24,  5.10it/s]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  77%|███████▋  | 409/534 [10:33<00:24,  5.18it/s]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  77%|███████▋  | 410/534 [10:34<00:23,  5.33it/s]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  77%|███████▋  | 411/534 [10:34<00:23,  5.31it/s]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  77%|███████▋  | 412/534 [10:34<00:22,  5.38it/s]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  77%|███████▋  | 413/534 [10:34<00:22,  5.33it/s]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  78%|███████▊  | 414/534 [10:34<00:21,  5.49it/s]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  78%|███████▊  | 415/534 [10:34<00:21,  5.49it/s]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  78%|███████▊  | 416/534 [10:35<00:22,  5.27it/s]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  78%|███████▊  | 417/534 [10:54<11:31,  5.91s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  78%|███████▊  | 418/534 [10:54<08:06,  4.19s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  78%|███████▊  | 419/534 [10:54<05:44,  3.00s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  79%|███████▊  | 420/534 [10:54<04:04,  2.15s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  79%|███████▉  | 421/534 [10:55<02:55,  1.55s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  79%|███████▉  | 422/534 [10:55<02:07,  1.14s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  79%|███████▉  | 423/534 [10:55<01:34,  1.17it/s]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  79%|███████▉  | 424/534 [10:55<01:12,  1.52it/s]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  80%|███████▉  | 425/534 [10:55<00:56,  1.94it/s]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  80%|███████▉  | 426/534 [10:56<00:44,  2.42it/s]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  80%|███████▉  | 427/534 [10:56<00:36,  2.93it/s]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  80%|████████  | 428/534 [10:56<00:30,  3.44it/s]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  80%|████████  | 429/534 [10:56<00:27,  3.80it/s]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  81%|████████  | 430/534 [10:56<00:24,  4.22it/s]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  81%|████████  | 431/534 [10:56<00:22,  4.60it/s]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  81%|████████  | 432/534 [10:57<00:20,  4.95it/s]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  81%|████████  | 433/534 [10:57<00:19,  5.19it/s]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  81%|████████▏ | 434/534 [10:57<00:19,  5.17it/s]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  81%|████████▏ | 435/534 [10:57<00:18,  5.30it/s]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  82%|████████▏ | 436/534 [10:57<00:18,  5.38it/s]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  82%|████████▏ | 437/534 [10:58<00:17,  5.52it/s]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  82%|████████▏ | 438/534 [10:58<00:18,  5.14it/s]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  82%|████████▏ | 439/534 [10:58<00:17,  5.31it/s]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  82%|████████▏ | 440/534 [10:58<00:17,  5.33it/s]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  83%|████████▎ | 441/534 [10:58<00:21,  4.31it/s]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  83%|████████▎ | 442/534 [10:59<00:20,  4.44it/s]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  83%|████████▎ | 443/534 [10:59<00:19,  4.61it/s]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  83%|████████▎ | 444/534 [10:59<00:18,  4.80it/s]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  83%|████████▎ | 445/534 [10:59<00:17,  4.97it/s]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  84%|████████▎ | 446/534 [10:59<00:17,  5.17it/s]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  84%|████████▎ | 447/534 [11:00<00:16,  5.22it/s]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  84%|████████▍ | 448/534 [11:00<00:16,  5.30it/s]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  84%|████████▍ | 449/534 [11:00<00:17,  4.89it/s]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  84%|████████▍ | 450/534 [11:00<00:20,  4.13it/s]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  84%|████████▍ | 451/534 [11:01<00:18,  4.49it/s]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  85%|████████▍ | 452/534 [11:01<00:18,  4.41it/s]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  85%|████████▍ | 453/534 [11:01<00:18,  4.39it/s]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  85%|████████▌ | 454/534 [11:01<00:17,  4.48it/s]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  85%|████████▌ | 455/534 [11:02<00:20,  3.92it/s]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  85%|████████▌ | 456/534 [11:02<00:19,  4.04it/s]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  86%|████████▌ | 457/534 [11:02<00:18,  4.06it/s]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  86%|████████▌ | 458/534 [11:02<00:18,  4.03it/s]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  86%|████████▌ | 459/534 [11:03<00:19,  3.88it/s]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  86%|████████▌ | 460/534 [11:03<00:18,  3.90it/s]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  86%|████████▋ | 461/534 [11:03<00:19,  3.71it/s]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  87%|████████▋ | 462/534 [11:03<00:21,  3.42it/s]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  87%|████████▋ | 463/534 [11:04<00:18,  3.86it/s]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  87%|████████▋ | 464/534 [11:04<00:16,  4.29it/s]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  87%|████████▋ | 465/534 [11:04<00:14,  4.60it/s]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  87%|████████▋ | 466/534 [11:04<00:14,  4.60it/s]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  87%|████████▋ | 467/534 [11:04<00:14,  4.76it/s]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  88%|████████▊ | 468/534 [11:05<00:13,  4.75it/s]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  88%|████████▊ | 469/534 [11:05<00:13,  5.00it/s]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  88%|████████▊ | 470/534 [11:05<00:12,  5.19it/s]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  88%|████████▊ | 471/534 [11:05<00:12,  4.96it/s]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  88%|████████▊ | 472/534 [11:05<00:11,  5.17it/s]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  89%|████████▊ | 473/534 [11:06<00:11,  5.15it/s]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  89%|████████▉ | 474/534 [11:06<00:11,  5.34it/s]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  89%|████████▉ | 475/534 [11:06<00:10,  5.50it/s]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  89%|████████▉ | 476/534 [11:06<00:10,  5.49it/s]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  89%|████████▉ | 477/534 [11:06<00:10,  5.34it/s]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  90%|████████▉ | 478/534 [11:06<00:10,  5.46it/s]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  90%|████████▉ | 479/534 [11:07<00:09,  5.51it/s]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  90%|████████▉ | 480/534 [11:07<00:09,  5.61it/s]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  90%|█████████ | 481/534 [11:07<00:09,  5.71it/s]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  90%|█████████ | 482/534 [11:07<00:09,  5.49it/s]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  90%|█████████ | 483/534 [11:07<00:09,  5.53it/s]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  91%|█████████ | 484/534 [11:08<00:09,  5.37it/s]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  91%|█████████ | 485/534 [11:08<00:08,  5.51it/s]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  91%|█████████ | 486/534 [11:08<00:08,  5.48it/s]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  91%|█████████ | 487/534 [11:26<04:26,  5.66s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  91%|█████████▏| 488/534 [11:45<07:25,  9.68s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  92%|█████████▏| 489/534 [11:46<05:07,  6.83s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  92%|█████████▏| 490/534 [11:46<03:32,  4.84s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  92%|█████████▏| 491/534 [11:46<02:28,  3.44s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  92%|█████████▏| 492/534 [11:46<01:43,  2.46s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  92%|█████████▏| 493/534 [11:46<01:13,  1.79s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  93%|█████████▎| 494/534 [11:47<00:52,  1.31s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  93%|█████████▎| 495/534 [11:47<00:38,  1.03it/s]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  93%|█████████▎| 496/534 [11:47<00:27,  1.37it/s]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  93%|█████████▎| 497/534 [11:47<00:21,  1.76it/s]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  93%|█████████▎| 498/534 [11:47<00:16,  2.22it/s]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  93%|█████████▎| 499/534 [12:06<03:27,  5.93s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  94%|█████████▎| 500/534 [12:06<02:23,  4.23s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  94%|█████████▍| 501/534 [12:07<01:41,  3.06s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  94%|█████████▍| 502/534 [12:07<01:10,  2.21s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  94%|█████████▍| 503/534 [12:07<00:49,  1.60s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  94%|█████████▍| 504/534 [12:07<00:35,  1.17s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  95%|█████████▍| 505/534 [12:07<00:25,  1.14it/s]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  95%|█████████▍| 506/534 [12:07<00:18,  1.50it/s]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  95%|█████████▍| 507/534 [12:08<00:14,  1.86it/s]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  95%|█████████▌| 508/534 [12:08<00:11,  2.25it/s]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  95%|█████████▌| 509/534 [12:08<00:09,  2.69it/s]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  96%|█████████▌| 510/534 [12:08<00:07,  3.17it/s]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  96%|█████████▌| 511/534 [12:08<00:06,  3.67it/s]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  96%|█████████▌| 512/534 [12:09<00:05,  4.12it/s]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  96%|█████████▌| 513/534 [12:09<00:04,  4.51it/s]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  96%|█████████▋| 514/534 [12:09<00:04,  4.69it/s]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  96%|█████████▋| 515/534 [12:09<00:03,  4.99it/s]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  97%|█████████▋| 516/534 [12:09<00:03,  5.10it/s]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  97%|█████████▋| 517/534 [12:10<00:03,  5.29it/s]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  97%|█████████▋| 518/534 [12:10<00:02,  5.41it/s]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  97%|█████████▋| 519/534 [12:10<00:02,  5.36it/s]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  97%|█████████▋| 520/534 [12:10<00:02,  5.29it/s]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  98%|█████████▊| 521/534 [12:10<00:02,  5.03it/s]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  98%|█████████▊| 522/534 [12:11<00:02,  5.15it/s]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  98%|█████████▊| 523/534 [12:11<00:02,  4.98it/s]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  98%|█████████▊| 524/534 [12:11<00:01,  5.24it/s]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  98%|█████████▊| 525/534 [12:11<00:02,  3.86it/s]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  99%|█████████▊| 526/534 [12:30<00:46,  5.77s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  99%|█████████▊| 527/534 [12:30<00:28,  4.11s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  99%|█████████▉| 528/534 [12:30<00:17,  2.94s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  99%|█████████▉| 529/534 [12:31<00:10,  2.12s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  99%|█████████▉| 530/534 [12:31<00:06,  1.57s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
#  99%|█████████▉| 531/534 [12:31<00:03,  1.21s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# 100%|█████████▉| 532/534 [12:32<00:02,  1.01s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# 100%|█████████▉| 533/534 [12:32<00:00,  1.31it/s]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# 100%|██████████| 534/534 [12:32<00:00,  1.41s/it]

# %%
# !pip install rouge-score
# Out:
# Collecting rouge-score
#   Downloading rouge_score-0.1.2.tar.gz (17 kB)
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: absl-py in /usr/local/lib/python3.10/dist-packages (from rouge-score) (1.4.0)
# Requirement already satisfied: nltk in /usr/local/lib/python3.10/dist-packages (from rouge-score) (3.9.1)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from rouge-score) (1.26.4)
# Requirement already satisfied: six>=1.14.0 in /usr/local/lib/python3.10/dist-packages (from rouge-score) (1.17.0)
# Requirement already satisfied: click in /usr/local/lib/python3.10/dist-packages (from nltk->rouge-score) (8.1.7)
# Requirement already satisfied: joblib in /usr/local/lib/python3.10/dist-packages (from nltk->rouge-score) (1.4.2)
# Requirement already satisfied: regex>=2021.8.3 in /usr/local/lib/python3.10/dist-packages (from nltk->rouge-score) (2024.9.11)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from nltk->rouge-score) (4.66.6)
# Building wheels for collected packages: rouge-score
#   Building wheel for rouge-score (setup.py) ... done
#   Created wheel for rouge-score: filename=rouge_score-0.1.2-py3-none-any.whl size=24935 sha256=cad2a51d79f28ad0e4e430102cf4e065eda38af16ba826c0fc6feb9e5d5e108e
#   Stored in directory: /root/.cache/pip/wheels/5f/dd/89/461065a73be61a532ff8599a28e9beef17985c9e9c31e541b4
# Successfully built rouge-score
# Installing collected packages: rouge-score
# Successfully installed rouge-score-0.1.2

# %%
from nltk.translate.bleu_score import corpus_bleu
from rouge_score import rouge_scorer
from nltk.translate.meteor_score import meteor_score
import nltk
nltk.download('punkt')
nltk.download('punkt_tab')
nltk.download('wordnet')
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# [nltk_data] Downloading package punkt_tab to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt_tab.zip.
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# True

# %%
def evaluate_generated_comments(reference_comments, generated_comments):

    # Tokenize for BLEU
    tokenized_generated = [nltk.word_tokenize(comment.lower()) for comment in generated_comments]
    tokenized_reference = [[nltk.word_tokenize(ref.lower())] for ref in reference_comments]

    # BLEU-2
    bleu_score = corpus_bleu(tokenized_reference, tokenized_generated, weights=(0.5, 0.5))  # BLEU-2

    # ROUGE
    scorer = rouge_scorer.RougeScorer(['rouge1', 'rouge2', 'rougeL'], use_stemmer=True)
    rouge1, rouge2, rougeL = 0, 0, 0
    for ref, gen in zip(reference_comments, generated_comments):
        scores = scorer.score(ref, gen)
        rouge1 += scores['rouge1'].fmeasure
        rouge2 += scores['rouge2'].fmeasure
        rougeL += scores['rougeL'].fmeasure
    rouge1 /= len(reference_comments)
    rouge2 /= len(reference_comments)
    rougeL /= len(reference_comments)

    # METEOR
    meteor = 0
    for ref, gen in zip(reference_comments, generated_comments):
        # Tokenize the hypothesis and references
        ref_tokens = nltk.word_tokenize(ref.lower())
        gen_tokens = nltk.word_tokenize(gen.lower())

        # Compute METEOR for each pair
        meteor += meteor_score([ref_tokens], gen_tokens)
    meteor /= len(reference_comments)

    return {
        'BLEU-2': bleu_score,
        'ROUGE-1': rouge1,
        'ROUGE-2': rouge2,
        'ROUGE-L': rougeL,
        'METEOR': meteor
    }

# %%
metrics = evaluate_generated_comments(reference_comments, generated_comments)
for metric, score in metrics.items():
    print(f"{metric}: {score:.4f}")
# Out:
# BLEU-2: 0.0425
# ROUGE-1: 0.1946
# ROUGE-2: 0.0400
# ROUGE-L: 0.1332
# METEOR: 0.1537

# %%
from sentence_transformers import SentenceTransformer
from sklearn.metrics.pairwise import cosine_similarity

# %%
# Load a pre-trained Sentence-BERT model
model = SentenceTransformer('all-MiniLM-L6-v2')
# Out:
# modules.json:   0%|          | 0.00/349 [00:00<?, ?B/s]
# config_sentence_transformers.json:   0%|          | 0.00/116 [00:00<?, ?B/s]
# README.md:   0%|          | 0.00/10.7k [00:00<?, ?B/s]
# sentence_bert_config.json:   0%|          | 0.00/53.0 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/612 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/90.9M [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/350 [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/232k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/466k [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/112 [00:00<?, ?B/s]
# 1_Pooling/config.json:   0%|          | 0.00/190 [00:00<?, ?B/s]

# %%
# Encode the comments to get their embeddings
embeddings_ref = model.encode(reference_comments)
embeddings_gen = model.encode(generated_comments)

# %%
# Compute cosine similarity for each pair
similarity_scores = cosine_similarity(embeddings_ref, embeddings_gen).diagonal()

# Calculate average similarity
average_similarity = similarity_scores.mean()



print(f"\nAverage Cosine Similarity: {average_similarity:.4f}")
# Out:
# Average Cosine Similarity: 0.5300

# %%
print(reference_comments[0])
print("__________")
print(generated_comments[0])
